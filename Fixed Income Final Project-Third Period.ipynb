# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm 
import os
from datetime import date
import datetime as dt
import scipy.stats as stats
import scipy
from scipy.optimize import root
import math

# %%
file_path = 'USS01.xlsx'
sheets_dict = pd.read_excel(file_path, sheet_name=None, parse_dates=['Date'], index_col='Date')
print(sheets_dict.keys())
# Out:
# dict_keys(['1yr Swap', '1m1yr', '3m1yr', '6m1yr', '1yr1yr', '2yr1yr', '5yr1yr'])

# %%
dfs = []
sheet_name = ['1yr Swap', '1m1yr', '3m1yr', '6m1yr', '1yr1yr', '2yr1yr', '5yr1yr']
for name in sheet_name:
    df = pd.DataFrame(sheets_dict[name])
    dfs.append(df)

# %%
USS01= dfs[0].iloc[1:, -1:]
USS1m1y = dfs[1].iloc[1:, -1:]
USS3m1y = dfs[2].iloc[1:, -1:]
USS6m1y = dfs[3].iloc[1:, -1:]
USS1y1y = dfs[4].iloc[1:, -1:]
USS2y1y = dfs[5].iloc[1:, -1:]
USS5y1y = dfs[6].iloc[1:, -1:]
USS01
# Out:
#              Close
# Date
# 2023-04-19  4.9243
# 2023-04-18  4.8878
# 2023-04-17  4.8776
# 2023-04-14  4.8184
# 2023-04-13  4.7038
# ...            ...
# 2018-04-27  2.1054
# 2018-04-26  2.1070
# 2018-04-25  2.1031
# 2018-04-24  2.0938
# 2018-04-23  2.0960
#
# [1294 rows x 1 columns]

# %%
file_path = 'USS02.xlsx'
sheets_dict = pd.read_excel(file_path, sheet_name=None, parse_dates=['Date'], index_col='Date')
print(sheets_dict.keys())
# Out:
# dict_keys(['2 yr Swap', '1m2yr', '3m2yr', '6m2yr', '1yr2yr', '2yr2yr', '5yr2yr'])

# %%
dfs = []
sheet_name = ['2 yr Swap', '1m2yr', '3m2yr', '6m2yr', '1yr2yr', '2yr2yr', '5yr2yr']
for name in sheet_name:
    df = pd.DataFrame(sheets_dict[name])
    dfs.append(df)

# %%
USS02= dfs[0].iloc[1:,:]
USS1m2y = dfs[1].iloc[1:-1:]
USS3m2y = dfs[2].iloc[1:,-1:]
USS6m2y = dfs[3].iloc[1:,-1:]
USS1y2y = dfs[4].iloc[1:,-1:]
USS2y2y = dfs[5].iloc[1:,-1:]
USS5y2y = dfs[6].iloc[1:,-1:]
USS1m2y
# Out:
#             Last Price
# Date
# 2023-04-19    166.4000
# 2023-04-18    165.1000
# 2023-04-17    169.2000
# 2023-04-14    167.2000
# 2023-04-13    169.2000
# ...                ...
# 2018-04-30     35.6000
# 2018-04-27     35.5000
# 2018-04-26     37.8000
# 2018-04-25     40.3593
# 2018-04-24     40.9500
#
# [1292 rows x 1 columns]

# %%
file_path = 'USS05.xlsx'
sheets_dict = pd.read_excel(file_path, sheet_name=None,parse_dates=['Date'], index_col='Date')
print(sheets_dict.keys())
# Out:
# dict_keys(['5 yr Swap', '1m5yr', '3m5yr', '6m5yr', '1yr5yr', '2yr5yr', '5yr5yr'])

# %%
dfs = []
sheet_name = ['5 yr Swap', '1m5yr', '3m5yr', '6m5yr', '1yr5yr', '2yr5yr', '5yr5yr']
for name in sheet_name:
    df = pd.DataFrame(sheets_dict[name])
    dfs.append(df)

# %%
USS05= dfs[0].iloc[1:,-1:]
USS1m5y = dfs[1].iloc[1:,-1:]
USS3m5y = dfs[2].iloc[1:,-1:]
USS6m5y = dfs[3].iloc[1:,-1:]
USS1y5y = dfs[4].iloc[1:,-1:]
USS2y5y = dfs[5].iloc[1:,-1:]
USS5y5y = dfs[6].iloc[1:,-1:]
USS05
# Out:
#             Last Price
# Date
# 2023-04-19      3.4895
# 2023-04-18      3.4729
# 2023-04-17      3.4878
# 2023-04-14      3.3861
# 2023-04-13      3.2829
# ...                ...
# 2018-04-27      2.5250
# 2018-04-26      2.5390
# 2018-04-25      2.5640
# 2018-04-24      2.5450
# 2018-04-23      2.5380
#
# [1292 rows x 1 columns]

# %%
file_path = 'USS010.xlsx'
sheets_dict = pd.read_excel(file_path, sheet_name=None, parse_dates=['Date'], index_col='Date')
print(sheets_dict.keys())
# Out:
# dict_keys(['10 yr Swap', '1m10yr', '3m10yr', '6m10yr', '1yr10yr', '2yr10yr', '5yr10yr'])

# %%
dfs = []
sheet_name = ['10 yr Swap', '1m10yr', '3m10yr', '6m10yr', '1yr10yr', '2yr10yr', '5yr10yr']
for name in sheet_name:
    df = pd.DataFrame(sheets_dict[name])
    dfs.append(df)

# %%
USS010= dfs[0].iloc[1:, -1:]
USS1m10y = dfs[1].iloc[1:, -1:]
USS3m10y = dfs[2].iloc[1:, -1:]
USS6m10y = dfs[3].iloc[1:, -1:]
USS1y10y = dfs[4].iloc[1:, -1:]
USS2y10y = dfs[5].iloc[1:, -1:]
USS5y10y = dfs[6].iloc[1:, -1:]
USS010
# Out:
#              Close
# Date
# 2023-04-19  3.2934
# 2023-04-18  3.2870
# 2023-04-17  3.3010
# 2023-04-14  3.2080
# 2023-04-13  3.1390
# ...            ...
# 2018-04-27  2.5700
# 2018-04-26  2.5950
# 2018-04-25  2.6380
# 2018-04-24  2.6070
# 2018-04-23  2.5850
#
# [1292 rows x 1 columns]

# %%
file_path = 'USS030.xlsx'
sheets_dict = pd.read_excel(file_path, sheet_name=None, parse_dates=['Date'], index_col='Date')
print(sheets_dict.keys())
# Out:
# dict_keys(['30yr Swap', '1m30yr', '3m30yr', '6m30yr', '1yr30yr', '2yr30yr', '5yr30yr'])

# %%
dfs = []
sheet_name = ['30yr Swap', '1m30yr', '3m30yr', '6m30yr', '1yr30yr', '2yr30yr', '5yr30yr']
for name in sheet_name:
    df = pd.DataFrame(sheets_dict[name])
    dfs.append(df)

# %%
USS030= dfs[0].iloc[1:, -1:]
USS1m30y = dfs[1].iloc[1:, -1:]
USS3m30y = dfs[2].iloc[1:, -1:]
USS6m30y = dfs[3].iloc[1:, -1:]
USS1y30y = dfs[4].iloc[1:, -1:]
USS2y30y = dfs[5].iloc[1:, -1:]
USS5y30y = dfs[6].iloc[1:, -1:]
USS030
# Out:
#              Close
# Date
# 2023-04-19  3.0584
# 2023-04-18  3.0630
# 2023-04-17  3.0735
# 2023-04-14  2.9925
# 2023-04-13  2.9440
# ...            ...
# 2018-04-27  2.5380
# 2018-04-26  2.5690
# 2018-04-25  2.6040
# 2018-04-24  2.5710
# 2018-04-23  2.5380
#
# [1295 rows x 1 columns]

# %%
swap_merged=pd.merge(USS01,USS02,how='inner',on='Date')
swap_merged=pd.merge(swap_merged,USS05,how='inner',on='Date')
swap_merged=pd.merge(swap_merged,USS010,how='inner',on='Date')
swap_merged=pd.merge(swap_merged,USS030,how='inner',on='Date')

# %%
swap_merged
# Out:
#             Close_x  Last Price_x  Last Price_y  Close_y   Close
# Date
# 2023-04-19   4.9243        4.2539        3.4895   3.2934  3.0584
# 2023-04-18   4.8878        4.2070        3.4729   3.2870  3.0630
# 2023-04-17   4.8776        4.2115        3.4878   3.3010  3.0735
# 2023-04-14   4.8184        4.1120        3.3861   3.2080  2.9925
# 2023-04-13   4.7038        3.9815        3.2829   3.1390  2.9440
# ...             ...           ...           ...      ...     ...
# 2018-04-27   2.1054        2.3380        2.5250   2.5700  2.5380
# 2018-04-26   2.1070        2.3383        2.5390   2.5950  2.5690
# 2018-04-25   2.1031        2.3411        2.5640   2.6380  2.6040
# 2018-04-24   2.0938        2.3366        2.5450   2.6070  2.5710
# 2018-04-23   2.0960        2.3410        2.5380   2.5850  2.5380
#
# [1288 rows x 5 columns]

# %%
plt.figure(figsize=(15, 10))
plt.plot(swap_merged.index, swap_merged['Close_x'], label = "USS01")
plt.plot(swap_merged.index, swap_merged['Last Price_x'], label = "USS02")
plt.plot(swap_merged.index, swap_merged['Last Price_y'], label = "USS05")
plt.plot(swap_merged.index, swap_merged['Close_y'], label = "USS010")
plt.plot(swap_merged.index, swap_merged['Close'], label = "USS030")
plt.legend()

# %%
swaption_merged_1m=pd.merge(USS1m1y,USS1m2y,how='inner',on='Date')
swaption_merged_1m=pd.merge(swaption_merged_1m,USS1m5y,how='inner',on='Date')
swaption_merged_1m=pd.merge(swaption_merged_1m,USS1m10y,how='inner',on='Date')
swaption_merged_1m=pd.merge(swaption_merged_1m,USS1m30y,how='inner',on='Date')

# %%
plt.figure(figsize=(15, 10))
plt.plot(swaption_merged_1m.index, swaption_merged_1m['Close_x'], label = "USS1m1y")
plt.plot(swaption_merged_1m.index, swaption_merged_1m['Last Price_x'], label = "USS1m2y")
plt.plot(swaption_merged_1m.index, swaption_merged_1m['Last Price_y'], label = "USS1m5y")
plt.plot(swaption_merged_1m.index, swaption_merged_1m['Close_y'], label = "USS1m10y")
plt.plot(swaption_merged_1m.index, swaption_merged_1m['Close'], label = "USS1m30y")
plt.legend()

# %% [markdown]
# ## 1 YEAR SWAP DATA FRAME

# %%
swap_1yr_merged=pd.merge(USS01,USS1m1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close_x':'1yr Swap'}, inplace = True)
swap_1yr_merged.rename(columns = {'Close_y':'1m Expiry'}, inplace = True)

# %%
swap_1yr_merged=pd.merge(swap_1yr_merged,USS3m1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close':'3m Expiry'}, inplace = True)

# %%
swap_1yr_merged=pd.merge(swap_1yr_merged,USS6m1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close':'6m Expiry'}, inplace = True)

# %%
swap_1yr_merged=pd.merge(swap_1yr_merged,USS1y1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close':'1yr Expiry'}, inplace = True)

# %%
swap_1yr_merged=pd.merge(swap_1yr_merged,USS2y1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close':'2yr Expiry'}, inplace = True)

# %%
swap_1yr_merged=pd.merge(swap_1yr_merged,USS5y1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close':'5yr Expiry'}, inplace = True)

# %%
swap_1yr_merged
# Out:
#             1yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2023-04-19    4.9243   153.3449   153.0000   153.2000    153.9000    136.9000
# 2023-04-18    4.8878   153.5600   151.4000   151.8000    152.8000    135.5000
# 2023-04-17    4.8776   154.9750   154.2000   154.2000    150.9000    135.2000
# 2023-04-14    4.8184   160.5883   154.7000   154.5000    149.6000    132.3000
# 2023-04-13    4.7038   166.3000   160.9000   161.2000    153.0000    134.1000
# ...              ...        ...        ...        ...         ...         ...
# 2018-04-27    2.1054    26.6248    32.1073    37.4925     46.7418     62.5986
# 2018-04-26    2.1070    27.9066    34.0906    39.6118     47.5000     63.4476
# 2018-04-25    2.1031    30.1568    35.3982    40.8817     49.6592     64.4074
# 2018-04-24    2.0938    29.9912    34.9173    40.2930     48.8168     63.9111
# 2018-04-23    2.0960    30.8623    36.0257    40.6542     49.3488     63.2212
#
#             5yr Expiry
# Date
# 2023-04-19    106.6000
# 2023-04-18    106.0000
# 2023-04-17    106.2000
# 2023-04-14    105.7000
# 2023-04-13    105.6000
# ...                ...
# 2018-04-27     75.7315
# 2018-04-26     76.8627
# 2018-04-25     77.0243
# 2018-04-24     76.5127
# 2018-04-23     75.4768
#
# [1283 rows x 7 columns]

# %%
swap_1yr_merged=swap_1yr_merged.loc['2021-02-01':'2022-12-31']

# %%
swap_1yr_merged
# Out:
#             1yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    4.9060   106.2248   119.5000   129.3000    147.4000    145.0000
# 2022-12-29    4.8741   106.0491   115.7000   126.5000    144.4000    144.3000
# 2022-12-28    4.8695   105.0090   118.3000   129.0000    147.1000    145.8000
# 2022-12-27    4.8901   107.0000   117.8000   128.5000    146.5000    145.5000
# 2022-12-23    4.8410   102.1645   115.9000   126.4000    143.9000    143.8000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.0730    10.8811    10.5909    12.6758     17.6081     32.2358
# 2021-02-04    0.0710    11.0603    11.4673    12.1887     17.0383     31.0143
# 2021-02-03    0.0720    11.0480    11.5464    11.6582     16.7627     31.2117
# 2021-02-02    0.0740    11.0373    11.4593    11.6281     16.6887     30.7545
# 2021-02-01    0.0720    11.0287    11.5314    11.6237     16.3582     30.2982
#
#             5yr Expiry
# Date
# 2022-12-30    124.1000
# 2022-12-29    122.1000
# 2022-12-28    122.0000
# 2022-12-27    120.5000
# 2022-12-23    119.8000
# ...                ...
# 2021-02-05     60.6018
# 2021-02-04     60.5614
# 2021-02-03     59.7250
# 2021-02-02     60.0868
# 2021-02-01     59.5498
#
# [485 rows x 7 columns]

# %%
fwd_rate= 2 * np.log(0.5 * (swap_1yr_merged["1yr Swap"]/100) + 1)*10000

# %%
swap_1yr_merged["Forward_Rate"] =fwd_rate

# %%
swap_1yr_merged
# Out:
#             1yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    4.9060   106.2248   119.5000   129.3000    147.4000    145.0000
# 2022-12-29    4.8741   106.0491   115.7000   126.5000    144.4000    144.3000
# 2022-12-28    4.8695   105.0090   118.3000   129.0000    147.1000    145.8000
# 2022-12-27    4.8901   107.0000   117.8000   128.5000    146.5000    145.5000
# 2022-12-23    4.8410   102.1645   115.9000   126.4000    143.9000    143.8000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.0730    10.8811    10.5909    12.6758     17.6081     32.2358
# 2021-02-04    0.0710    11.0603    11.4673    12.1887     17.0383     31.0143
# 2021-02-03    0.0720    11.0480    11.5464    11.6582     16.7627     31.2117
# 2021-02-02    0.0740    11.0373    11.4593    11.6281     16.6887     30.7545
# 2021-02-01    0.0720    11.0287    11.5314    11.6237     16.3582     30.2982
#
#             5yr Expiry  Forward_Rate
# Date
# 2022-12-30    124.1000    484.679417
# 2022-12-29    122.1000    481.565552
# 2022-12-28    122.0000    481.116490
# 2022-12-27    120.5000    483.127426
# 2022-12-23    119.8000    478.334038
# ...                ...           ...
# 2021-02-05     60.6018      7.298668
# 2021-02-04     60.5614      7.098740
# 2021-02-03     59.7250      7.198704
# 2021-02-02     60.0868      7.398631
# 2021-02-01     59.5498      7.198704
#
# [485 rows x 8 columns]

# %%
expiry=[1/12,3/12,1/2,1,2,5]

# %%
def annuity(tenor, expiry,forward_array):
    
    annuity_list = np.zeros(len(forward_array))
    for i in range(1,(tenor*2)+1):
        #print(i)
        
        #print(forward_array)
        annuity_list += 0.5 * np.exp(-0.5*( expiry+ i) * (forward_array/10000))
        #print(annuity_list)
    return annuity_list

# %%
swap_1yr_merged["1m1yr Annuity"] =annuity(1,1/12,swap_1yr_merged["Forward_Rate"])
swap_1yr_merged["3m1yr Annuity"] =annuity(1,3/12,swap_1yr_merged["Forward_Rate"])
swap_1yr_merged["6m1yr Annuity"] =annuity(1,1/2,swap_1yr_merged["Forward_Rate"])
swap_1yr_merged["1yr1yr Annuity"] =annuity(1,1,swap_1yr_merged["Forward_Rate"])
swap_1yr_merged["2yr1yr Annuity"] =annuity(1,2,swap_1yr_merged["Forward_Rate"])
swap_1yr_merged["5yr1yr Annuity"] =annuity(1,5,swap_1yr_merged["Forward_Rate"])

# %%
swap_1yr_merged
# Out:
#             1yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    4.9060   106.2248   119.5000   129.3000    147.4000    145.0000
# 2022-12-29    4.8741   106.0491   115.7000   126.5000    144.4000    144.3000
# 2022-12-28    4.8695   105.0090   118.3000   129.0000    147.1000    145.8000
# 2022-12-27    4.8901   107.0000   117.8000   128.5000    146.5000    145.5000
# 2022-12-23    4.8410   102.1645   115.9000   126.4000    143.9000    143.8000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.0730    10.8811    10.5909    12.6758     17.6081     32.2358
# 2021-02-04    0.0710    11.0603    11.4673    12.1887     17.0383     31.0143
# 2021-02-03    0.0720    11.0480    11.5464    11.6582     16.7627     31.2117
# 2021-02-02    0.0740    11.0373    11.4593    11.6281     16.6887     30.7545
# 2021-02-01    0.0720    11.0287    11.5314    11.6237     16.3582     30.2982
#
#             5yr Expiry  Forward_Rate  1m1yr Annuity  3m1yr Annuity  \
# Date
# 2022-12-30    124.1000    484.679417       0.962427       0.958548
# 2022-12-29    122.1000    481.565552       0.962663       0.958808
# 2022-12-28    122.0000    481.116490       0.962697       0.958845
# 2022-12-27    120.5000    483.127426       0.962545       0.958677
# 2022-12-23    119.8000    478.334038       0.962909       0.959078
# ...                ...           ...            ...            ...
# 2021-02-05     60.6018      7.298668       0.999422       0.999362
# 2021-02-04     60.5614      7.098740       0.999438       0.999379
# 2021-02-03     59.7250      7.198704       0.999430       0.999370
# 2021-02-02     60.0868      7.398631       0.999414       0.999353
# 2021-02-01     59.5498      7.198704       0.999430       0.999370
#
#             6m1yr Annuity  1yr1yr Annuity  2yr1yr Annuity  5yr1yr Annuity
# Date
# 2022-12-30       0.952758        0.941283        0.918746        0.854322
# 2022-12-29       0.953054        0.941648        0.919246        0.855186
# 2022-12-28       0.953096        0.941701        0.919318        0.855311
# 2022-12-27       0.952905        0.941465        0.918995        0.854752
# 2022-12-23       0.953361        0.942028        0.919765        0.856084
# ...                   ...             ...             ...             ...
# 2021-02-05       0.999270        0.999088        0.998724        0.997631
# 2021-02-04       0.999290        0.999113        0.998759        0.997696
# 2021-02-03       0.999280        0.999101        0.998741        0.997663
# 2021-02-02       0.999260        0.999076        0.998706        0.997598
# 2021-02-01       0.999280        0.999101        0.998741        0.997663
#
# [485 rows x 14 columns]

# %%
def bachelier_call(strike_premium,T,sigma,A):
    
    d1=strike_premium/ (sigma* math.sqrt(T))
    P= A*sigma*math.sqrt(T)*((d1*norm.cdf(d1))+norm.pdf(d1))    
    return P

# %%
swap_1yr_merged["1m1yr Premium"]=bachelier_call(0,1/12,swap_1yr_merged['1m Expiry']/10000,swap_1yr_merged['1m1yr Annuity'])*10000
swap_1yr_merged["3m1yr Premium"]=bachelier_call(0,3/12,swap_1yr_merged['3m Expiry']/10000,swap_1yr_merged['3m1yr Annuity'])*10000
swap_1yr_merged["6m1yr Premium"]=bachelier_call(0,1/2,swap_1yr_merged['6m Expiry']/10000,swap_1yr_merged['6m1yr Annuity'])*10000
swap_1yr_merged["1yr1yr Premium"]=bachelier_call(0,1,swap_1yr_merged['1yr Expiry']/10000,swap_1yr_merged['1yr1yr Annuity'])*10000
swap_1yr_merged["2yr1yr Premium"]=bachelier_call(0,2,swap_1yr_merged['2yr Expiry']/10000,swap_1yr_merged['2yr1yr Annuity'])*10000
swap_1yr_merged["5yr1yr Premium"]=bachelier_call(0,5,swap_1yr_merged['5yr Expiry']/10000,swap_1yr_merged['5yr1yr Annuity'])*10000

# %%
swap_1yr_merged
# Out:
#             1yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    4.9060   106.2248   119.5000   129.3000    147.4000    145.0000
# 2022-12-29    4.8741   106.0491   115.7000   126.5000    144.4000    144.3000
# 2022-12-28    4.8695   105.0090   118.3000   129.0000    147.1000    145.8000
# 2022-12-27    4.8901   107.0000   117.8000   128.5000    146.5000    145.5000
# 2022-12-23    4.8410   102.1645   115.9000   126.4000    143.9000    143.8000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.0730    10.8811    10.5909    12.6758     17.6081     32.2358
# 2021-02-04    0.0710    11.0603    11.4673    12.1887     17.0383     31.0143
# 2021-02-03    0.0720    11.0480    11.5464    11.6582     16.7627     31.2117
# 2021-02-02    0.0740    11.0373    11.4593    11.6281     16.6887     30.7545
# 2021-02-01    0.0720    11.0287    11.5314    11.6237     16.3582     30.2982
#
#             5yr Expiry  Forward_Rate  1m1yr Annuity  3m1yr Annuity  \
# Date
# 2022-12-30    124.1000    484.679417       0.962427       0.958548
# 2022-12-29    122.1000    481.565552       0.962663       0.958808
# 2022-12-28    122.0000    481.116490       0.962697       0.958845
# 2022-12-27    120.5000    483.127426       0.962545       0.958677
# 2022-12-23    119.8000    478.334038       0.962909       0.959078
# ...                ...           ...            ...            ...
# 2021-02-05     60.6018      7.298668       0.999422       0.999362
# 2021-02-04     60.5614      7.098740       0.999438       0.999379
# 2021-02-03     59.7250      7.198704       0.999430       0.999370
# 2021-02-02     60.0868      7.398631       0.999414       0.999353
# 2021-02-01     59.5498      7.198704       0.999430       0.999370
#
#             6m1yr Annuity  1yr1yr Annuity  2yr1yr Annuity  5yr1yr Annuity  \
# Date
# 2022-12-30       0.952758        0.941283        0.918746        0.854322
# 2022-12-29       0.953054        0.941648        0.919246        0.855186
# 2022-12-28       0.953096        0.941701        0.919318        0.855311
# 2022-12-27       0.952905        0.941465        0.918995        0.854752
# 2022-12-23       0.953361        0.942028        0.919765        0.856084
# ...                   ...             ...             ...             ...
# 2021-02-05       0.999270        0.999088        0.998724        0.997631
# 2021-02-04       0.999290        0.999113        0.998759        0.997696
# 2021-02-03       0.999280        0.999101        0.998741        0.997663
# 2021-02-02       0.999260        0.999076        0.998706        0.997598
# 2021-02-01       0.999280        0.999101        0.998741        0.997663
#
#             1m1yr Premium  3m1yr Premium  6m1yr Premium  1yr1yr Premium  \
# Date
# 2022-12-30      11.773706      22.848709      34.751705       55.351288
# 2022-12-29      11.757118      22.128147      34.009711       54.245794
# 2022-12-28      11.642220      22.626294      34.683392       55.263180
# 2022-12-27      11.861079      22.526713      34.542035       55.023970
# 2022-12-23      11.329340      22.172645      33.993776       54.079751
# ...                   ...            ...            ...             ...
# 2021-02-05       1.252395       2.111230       3.573168        7.018210
# 2021-02-04       1.273041       2.285975       3.435929        6.791270
# 2021-02-03       1.271615       2.301723       3.286351        6.681335
# 2021-02-02       1.270363       2.284320       3.277800        6.651674
# 2021-02-01       1.269393       2.298733       3.276626        6.520108
#
#             2yr1yr Premium  5yr1yr Premium
# Date
# 2022-12-30       75.160311       94.577605
# 2022-12-29       74.838168       93.147520
# 2022-12-28       75.622044       93.084803
# 2022-12-27       75.439936       91.880305
# 2022-12-23       74.620968       91.488844
# ...                    ...             ...
# 2021-02-05       18.163888       53.932484
# 2021-02-04       17.476221       53.900032
# 2021-02-03       17.587147       53.153904
# 2021-02-02       17.328918       53.472423
# 2021-02-01       17.072408       52.997980
#
# [485 rows x 20 columns]

# %%
swap_1yr_merged.to_excel("output1.xlsx")

# %%
import numpy as np
from scipy.stats import norm

N_prime = norm.pdf
N = norm.cdf


def black_scholes_call(S, K, T, r, sigma):
    '''

    :param S: Asset price
    :param K: Strike price
    :param T: Time to maturity
    :param r: risk-free rate (treasury bills)
    :param sigma: volatility
    :return: call price
    '''

    ###standard black-scholes formula
    d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)

    call = S * N(d1) -  N(d2)* K * np.exp(-r * T)
    return call

def vega(S, K, T, r, sigma):
    '''

    :param S: Asset price
    :param K: Strike price
    :param T: Time to Maturity
    :param r: risk-free rate (treasury bills)
    :param sigma: volatility
    :return: partial derivative w.r.t volatility
    '''

    ### calculating d1 from black scholes
    d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

    #see hull derivatives chapter on greeks for reference
    vega = S * N_prime(d1) * np.sqrt(T)
    return vega



def implied_volatility_call(C, S, K, T, r,sig, tol=0.0001,
                            max_iterations=500):
    '''

    :param C: Observed call price
    :param S: Asset price
    :param K: Strike Price
    :param T: Time to Maturity
    :param r: riskfree rate
    :param tol: error tolerance in result
    :param max_iterations: max iterations to update vol
    :return: implied volatility in percent
    '''


    ### assigning initial volatility estimate for input in Newton_rap procedure
    sigma = sig
    
    for i in range(max_iterations):

        ### calculate difference between blackscholes price and market price with
        ### iteratively updated volality estimate
        diff = black_scholes_call(S, K, T, r, sigma) - C

        ###break if difference is less than specified tolerance level
        if abs(diff) < tol:
            #print(f'found on {i}th iteration')
            #print(f'difference is equal to {diff}')
            break

        ### use newton rapshon to update the estimate
        sigma = sigma - diff / vega(S, K, T, r, sigma)

    return sigma

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][14]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,1/12,0,0.5))
implied_vol_table_1yr=pd.DataFrame({"1m Implied Vol":price},index=swap_1yr_merged.index)

# %%
implied_vol_table_1yr.to_excel("output3.xlsx")

# %%
implied_vol_table_1yr
#implied_vol_table_1yr.max()
# Out:
#             1m Implied Vol
# Date
# 2022-12-30        0.208813
# 2022-12-29        0.209882
# 2022-12-28        0.208031
# 2022-12-27        0.211042
# 2022-12-23        0.203641
# ...                    ...
# 2021-02-05        0.500000
# 2021-02-04        0.500000
# 2021-02-03        0.500000
# 2021-02-02        0.500000
# 2021-02-01        0.500000
#
# [485 rows x 1 columns]

# %%
implied_vol_table_1yr.max()
# Out:
# 1m Implied Vol    3.359459
# dtype: float64

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][15]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,3/12,0,0.1))
implied_vol_table_1yr["3m Implied Vol"] =price

# %%
implied_vol_table_1yr.to_excel("output3.xlsx")

# %%
implied_vol_table_1yr
# Out:
#             1m Implied Vol  3m Implied Vol
# Date
# 2022-12-30        0.208813        0.233495
# 2022-12-29        0.209882        0.227612
# 2022-12-28        0.208031        0.232956
# 2022-12-27        0.211042        0.230953
# 2022-12-23        0.203641        0.229629
# ...                    ...             ...
# 2021-02-05        0.500000        1.449919
# 2021-02-04        0.500000        1.614150
# 2021-02-03        0.500000        1.602697
# 2021-02-02        0.500000        1.547591
# 2021-02-01        0.500000        1.600615
#
# [485 rows x 2 columns]

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][16]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,1/2,0,1.1))
implied_vol_table_1yr["6m Implied Vol"] =price

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][17]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,1,0,0.1))
implied_vol_table_1yr["1yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][18]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,2,0,5))
implied_vol_table_1yr["2yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][19]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,5,0,5))
implied_vol_table_1yr["5yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_1yr.to_excel("output3.xlsx")

# %%
implied_vol_table_1yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2022-12-30        0.208813        0.233495        0.251468         0.283077
# 2022-12-29        0.209882        0.227612        0.247700         0.279238
# 2022-12-28        0.208031        0.232956        0.252859         0.284746
# 2022-12-27        0.211042        0.230953        0.250762         0.282318
# 2022-12-23        0.203641        0.229629        0.249281         0.280287
# ...                    ...             ...             ...              ...
# 2021-02-05        0.500000        1.449919        1.774895         3.393938
# 2021-02-04        0.500000        1.614150        1.754876         3.361539
# 2021-02-03        0.500000        1.602697        1.655545         3.179198
# 2021-02-02        0.500000        1.547591        1.606806         3.005113
# 2021-02-01        0.500000        1.600615        1.650666         3.044204
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2022-12-30              NaN              NaN
# 2022-12-29              NaN              NaN
# 2022-12-28              NaN              NaN
# 2022-12-27              NaN              NaN
# 2022-12-23              NaN              NaN
# ...                     ...              ...
# 2021-02-05              NaN              NaN
# 2021-02-04              NaN              NaN
# 2021-02-03              NaN              NaN
# 2021-02-02              NaN              NaN
# 2021-02-01              NaN              NaN
#
# [485 rows x 6 columns]

# %% [markdown]
# ## 2 yr Swap Data Frame

# %%
swap_2yr_merged=pd.merge(USS02,USS1m2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price_x':'2yr Swap'}, inplace = True)
swap_2yr_merged.rename(columns = {'Last Price_y':'1m Expiry'}, inplace = True)

# %%
swap_2yr_merged=pd.merge(swap_2yr_merged,USS3m2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price':'3m Expiry'}, inplace = True)

# %%
swap_2yr_merged=pd.merge(swap_2yr_merged,USS6m2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price':'6m Expiry'}, inplace = True)

# %%
swap_2yr_merged=pd.merge(swap_2yr_merged,USS1y2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price':'1yr Expiry'}, inplace = True)

# %%
swap_2yr_merged=pd.merge(swap_2yr_merged,USS2y2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price':'2yr Expiry'}, inplace = True)

# %%
swap_2yr_merged=pd.merge(swap_2yr_merged,USS5y2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price':'5yr Expiry'}, inplace = True)

# %%
swap_2yr_merged
# Out:
#             2yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2023-04-19    4.2539   166.4000   157.8000   152.4000    144.9000    129.8000
# 2023-04-18    4.2070   165.1000   156.8000   150.7000    143.2000    128.5000
# 2023-04-17    4.2115   169.2000   159.7000   153.4000    142.9000    129.1000
# 2023-04-14    4.1120   167.2000   156.8000   150.4000    140.4000    127.2000
# 2023-04-13    3.9815   169.2000   163.2000   155.2000    143.0000    128.7000
# ...              ...        ...        ...        ...         ...         ...
# 2018-04-30    2.3440    35.6000    41.4143    47.0193     54.0398     65.5770
# 2018-04-27    2.3380    35.5000    43.8338    47.4723     54.4642     66.1209
# 2018-04-26    2.3383    37.8000    44.5189    48.8846     55.8512     66.8327
# 2018-04-25    2.3411    40.3593    46.4432    50.5287     57.7373     67.7000
# 2018-04-24    2.3366    40.9500    45.8284    49.6994     56.5584     67.0000
#
#             5yr Expiry
# Date
# 2023-04-19    103.0000
# 2023-04-18    102.3000
# 2023-04-17    102.5000
# 2023-04-14    101.9000
# 2023-04-13    102.2000
# ...                ...
# 2018-04-30     74.4516
# 2018-04-27     75.0327
# 2018-04-26     75.7000
# 2018-04-25     76.4000
# 2018-04-24     75.7000
#
# [1255 rows x 7 columns]

# %%
swap_2yr_merged=swap_2yr_merged.loc['2021-02-01':'2022-12-31']

# %%
swap_2yr_merged
# Out:
#             2yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    4.4500   126.2000   140.9000   144.0000    148.3000    143.6000
# 2022-12-29    4.4075   124.8000   138.6000   143.0000    147.1000    142.9000
# 2022-12-28    4.4145   124.8000   140.0000   144.2000    148.0000    143.4000
# 2022-12-27    4.4103   129.8000   139.3000   143.3000    147.9000    143.1000
# 2022-12-23    4.3561   117.4000   135.8000   139.8000    144.5000    140.5000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.0855    13.6400    13.8443    17.0342     24.7962     40.8000
# 2021-02-04    0.0838    13.6500    13.6877    16.9505     24.2471     40.0000
# 2021-02-03    0.0834    14.4000    13.6086    16.8692     23.8936     40.5174
# 2021-02-02    0.0826    13.4500    13.5126    16.7877     23.7950     39.8804
# 2021-02-01    0.0761    12.6183    13.5907    16.5039     23.6984     39.1742
#
#             5yr Expiry
# Date
# 2022-12-30    118.3000
# 2022-12-29    116.7000
# 2022-12-28    116.6000
# 2022-12-27    116.0000
# 2022-12-23    114.8000
# ...                ...
# 2021-02-05     61.2595
# 2021-02-04     60.7400
# 2021-02-03     60.1200
# 2021-02-02     59.8450
# 2021-02-01     60.2536
#
# [474 rows x 7 columns]

# %%
fwd_rate=f = 2 * np.log(0.5 * (swap_2yr_merged["2yr Swap"]/100) + 1)*10000

# %%
swap_2yr_merged["Forward_Rate"] =fwd_rate

# %%
swap_2yr_merged
# Out:
#             2yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    4.4500   126.2000   140.9000   144.0000    148.3000    143.6000
# 2022-12-29    4.4075   124.8000   138.6000   143.0000    147.1000    142.9000
# 2022-12-28    4.4145   124.8000   140.0000   144.2000    148.0000    143.4000
# 2022-12-27    4.4103   129.8000   139.3000   143.3000    147.9000    143.1000
# 2022-12-23    4.3561   117.4000   135.8000   139.8000    144.5000    140.5000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.0855    13.6400    13.8443    17.0342     24.7962     40.8000
# 2021-02-04    0.0838    13.6500    13.6877    16.9505     24.2471     40.0000
# 2021-02-03    0.0834    14.4000    13.6086    16.8692     23.8936     40.5174
# 2021-02-02    0.0826    13.4500    13.5126    16.7877     23.7950     39.8804
# 2021-02-01    0.0761    12.6183    13.5907    16.5039     23.6984     39.1742
#
#             5yr Expiry  Forward_Rate
# Date
# 2022-12-30    118.3000    440.121605
# 2022-12-29    116.7000    435.963677
# 2022-12-28    116.6000    436.648572
# 2022-12-27    116.0000    436.237638
# 2022-12-23    114.8000    430.933875
# ...                ...           ...
# 2021-02-05     61.2595      8.548173
# 2021-02-04     60.7400      8.378245
# 2021-02-03     60.1200      8.338262
# 2021-02-02     59.8450      8.258295
# 2021-02-01     60.2536      7.608553
#
# [474 rows x 8 columns]

# %%
swap_2yr_merged["1m2yr Annuity"] =annuity(2,1/12,swap_2yr_merged["Forward_Rate"])
swap_2yr_merged["3m2yr Annuity"] =annuity(2,3/12,swap_2yr_merged["Forward_Rate"])
swap_2yr_merged["6m2yr Annuity"] =annuity(2,1/2,swap_2yr_merged["Forward_Rate"])
swap_2yr_merged["1yr2yr Annuity"] =annuity(2,1,swap_2yr_merged["Forward_Rate"])
swap_2yr_merged["2yr2yr Annuity"] =annuity(2,2,swap_2yr_merged["Forward_Rate"])
swap_2yr_merged["5yr2yr Annuity"] =annuity(2,5,swap_2yr_merged["Forward_Rate"])

# %%
swap_2yr_merged
# Out:
#             2yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    4.4500   126.2000   140.9000   144.0000    148.3000    143.6000
# 2022-12-29    4.4075   124.8000   138.6000   143.0000    147.1000    142.9000
# 2022-12-28    4.4145   124.8000   140.0000   144.2000    148.0000    143.4000
# 2022-12-27    4.4103   129.8000   139.3000   143.3000    147.9000    143.1000
# 2022-12-23    4.3561   117.4000   135.8000   139.8000    144.5000    140.5000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.0855    13.6400    13.8443    17.0342     24.7962     40.8000
# 2021-02-04    0.0838    13.6500    13.6877    16.9505     24.2471     40.0000
# 2021-02-03    0.0834    14.4000    13.6086    16.8692     23.8936     40.5174
# 2021-02-02    0.0826    13.4500    13.5126    16.7877     23.7950     39.8804
# 2021-02-01    0.0761    12.6183    13.5907    16.5039     23.6984     39.1742
#
#             5yr Expiry  Forward_Rate  1m2yr Annuity  3m2yr Annuity  \
# Date
# 2022-12-30    118.3000    440.121605       1.890045       1.883126
# 2022-12-29    116.7000    435.963677       1.891050       1.884192
# 2022-12-28    116.6000    436.648572       1.890884       1.884016
# 2022-12-27    116.0000    436.237638       1.890984       1.884122
# 2022-12-23    114.8000    430.933875       1.892266       1.885483
# ...                ...           ...            ...            ...
# 2021-02-05     61.2595      8.548173       1.997793       1.997651
# 2021-02-04     60.7400      8.378245       1.997837       1.997698
# 2021-02-03     60.1200      8.338262       1.997847       1.997709
# 2021-02-02     59.8450      8.258295       1.997868       1.997730
# 2021-02-01     60.2536      7.608553       1.998036       1.997909
#
#             6m2yr Annuity  1yr2yr Annuity  2yr2yr Annuity  5yr2yr Annuity
# Date
# 2022-12-30       1.872794        1.852301        1.811984        1.696223
# 2022-12-29       1.873952        1.853639        1.813670        1.698861
# 2022-12-28       1.873761        1.853418        1.813392        1.698426
# 2022-12-27       1.873876        1.853550        1.813559        1.698687
# 2022-12-23       1.875354        1.855258        1.815711        1.702056
# ...                   ...             ...             ...             ...
# 2021-02-05       1.997437        1.997011        1.996157        1.993599
# 2021-02-04       1.997488        1.997070        1.996234        1.993726
# 2021-02-03       1.997500        1.997084        1.996252        1.993756
# 2021-02-02       1.997524        1.997112        1.996287        1.993816
# 2021-02-01       1.997719        1.997339        1.996579        1.994302
#
# [474 rows x 14 columns]

# %%
swap_2yr_merged["1m2yr Premium"]=bachelier_call(0,1/12,swap_2yr_merged['1m Expiry']/10000,swap_2yr_merged['1m2yr Annuity'])*10000
swap_2yr_merged["3m2yr Premium"]=bachelier_call(0,3/12,swap_2yr_merged['3m Expiry']/10000,swap_2yr_merged['3m2yr Annuity'])*10000
swap_2yr_merged["6m2yr Premium"]=bachelier_call(0,1/2,swap_2yr_merged['6m Expiry']/10000,swap_2yr_merged['6m2yr Annuity'])*10000
swap_2yr_merged["1yr2yr Premium"]=bachelier_call(0,1,swap_2yr_merged['1yr Expiry']/10000,swap_2yr_merged['1yr2yr Annuity'])*10000
swap_2yr_merged["2yr2yr Premium"]=bachelier_call(0,2,swap_2yr_merged['2yr Expiry']/10000,swap_2yr_merged['2yr2yr Annuity'])*10000
swap_2yr_merged["5yr2yr Premium"]=bachelier_call(0,5,swap_2yr_merged['5yr Expiry']/10000,swap_2yr_merged['5yr2yr Annuity'])*10000

# %%
swap_2yr_merged
# Out:
#             2yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    4.4500   126.2000   140.9000   144.0000    148.3000    143.6000
# 2022-12-29    4.4075   124.8000   138.6000   143.0000    147.1000    142.9000
# 2022-12-28    4.4145   124.8000   140.0000   144.2000    148.0000    143.4000
# 2022-12-27    4.4103   129.8000   139.3000   143.3000    147.9000    143.1000
# 2022-12-23    4.3561   117.4000   135.8000   139.8000    144.5000    140.5000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.0855    13.6400    13.8443    17.0342     24.7962     40.8000
# 2021-02-04    0.0838    13.6500    13.6877    16.9505     24.2471     40.0000
# 2021-02-03    0.0834    14.4000    13.6086    16.8692     23.8936     40.5174
# 2021-02-02    0.0826    13.4500    13.5126    16.7877     23.7950     39.8804
# 2021-02-01    0.0761    12.6183    13.5907    16.5039     23.6984     39.1742
#
#             5yr Expiry  Forward_Rate  1m2yr Annuity  3m2yr Annuity  \
# Date
# 2022-12-30    118.3000    440.121605       1.890045       1.883126
# 2022-12-29    116.7000    435.963677       1.891050       1.884192
# 2022-12-28    116.6000    436.648572       1.890884       1.884016
# 2022-12-27    116.0000    436.237638       1.890984       1.884122
# 2022-12-23    114.8000    430.933875       1.892266       1.885483
# ...                ...           ...            ...            ...
# 2021-02-05     61.2595      8.548173       1.997793       1.997651
# 2021-02-04     60.7400      8.378245       1.997837       1.997698
# 2021-02-03     60.1200      8.338262       1.997847       1.997709
# 2021-02-02     59.8450      8.258295       1.997868       1.997730
# 2021-02-01     60.2536      7.608553       1.998036       1.997909
#
#             6m2yr Annuity  1yr2yr Annuity  2yr2yr Annuity  5yr2yr Annuity  \
# Date
# 2022-12-30       1.872794        1.852301        1.811984        1.696223
# 2022-12-29       1.873952        1.853639        1.813670        1.698861
# 2022-12-28       1.873761        1.853418        1.813392        1.698426
# 2022-12-27       1.873876        1.853550        1.813559        1.698687
# 2022-12-23       1.875354        1.855258        1.815711        1.702056
# ...                   ...             ...             ...             ...
# 2021-02-05       1.997437        1.997011        1.996157        1.993599
# 2021-02-04       1.997488        1.997070        1.996234        1.993726
# 2021-02-03       1.997500        1.997084        1.996252        1.993756
# 2021-02-02       1.997524        1.997112        1.996287        1.993816
# 2021-02-01       1.997719        1.997339        1.996579        1.994302
#
#             1m2yr Premium  3m2yr Premium  6m2yr Premium  1yr2yr Premium  \
# Date
# 2022-12-30      27.469516      52.926164      76.075994      109.587932
# 2022-12-29      27.179221      52.091694      75.594391      108.779684
# 2022-12-28      27.176842      52.612966      76.220990      109.432214
# 2022-12-27      28.267143      52.352830      75.749896      109.366077
# 2022-12-23      25.584075      51.074299      73.958043      106.950367
# ...                   ...            ...            ...             ...
# 2021-02-05       3.138227       5.516589       9.598204       19.754933
# 2021-02-04       3.140597       5.454316       9.551286       19.318044
# 2021-02-03       3.313174       5.422826       9.505532       19.036538
# 2021-02-02       3.094628       5.384630       9.459721       18.958247
# 2021-02-01       2.903511       5.416236       9.300709       18.883429
#
#             2yr2yr Premium  5yr2yr Premium
# Date
# 2022-12-30      146.802652      179.004048
# 2022-12-29      146.222941      176.857570
# 2022-12-28      146.712095      176.660807
# 2022-12-27      146.418621      175.778734
# 2022-12-23      143.928946      174.305416
# ...                    ...             ...
# 2021-02-05       45.949414      108.944774
# 2021-02-04       45.050167      108.027771
# 2021-02-03       45.633302      106.926687
# 2021-02-02       44.916679      106.440776
# 2021-02-01       44.127747      107.193628
#
# [474 rows x 20 columns]

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][14]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,1/12,0,0.4))
implied_vol_table_2yr=pd.DataFrame({"1m Implied Vol":price},index=swap_2yr_merged.index)

# %%
implied_vol_table_2yr
# Out:
#             1m Implied Vol
# Date
# 2022-12-30        0.536232
# 2022-12-29        0.535681
# 2022-12-28        0.534786
# 2022-12-27        0.556761
# 2022-12-23        0.510203
# ...                    ...
# 2021-02-05        3.187377
# 2021-02-04        3.254488
# 2021-02-03        3.449778
# 2021-02-02        3.253442
# 2021-02-01        3.313240
#
# [474 rows x 1 columns]

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][15]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,3/12,0,2.4))
implied_vol_table_2yr["3m Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_2yr
# Out:
#             1m Implied Vol  3m Implied Vol
# Date
# 2022-12-30        0.536232        0.599912
# 2022-12-29        0.535681        0.596111
# 2022-12-28        0.534786        0.601169
# 2022-12-27        0.556761        0.598744
# 2022-12-23        0.510203        0.591321
# ...                    ...             ...
# 2021-02-05        3.187377        3.382162
# 2021-02-04        3.254488        3.410848
# 2021-02-03        3.449778        3.407531
# 2021-02-02        3.253442        3.416015
# 2021-02-01        3.313240        3.719371
#
# [474 rows x 2 columns]

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][16]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,1/2,0,1.3))
implied_vol_table_2yr["6m Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][17]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,1,0,2.9))
implied_vol_table_2yr["1yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][18]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,2,0,2.9))
implied_vol_table_2yr["2yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][19]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,5,0,4.9))
implied_vol_table_2yr["5yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_2yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2022-12-30        0.536232        0.599912        0.611136         0.627387
# 2022-12-29        0.535681        0.596111        0.613156         0.628813
# 2022-12-28        0.534786        0.601169        0.617326         0.631678
# 2022-12-27        0.556761        0.598744        0.614041         0.631905
# 2022-12-23        0.510203        0.591321        0.606861         0.625420
# ...                    ...             ...             ...              ...
# 2021-02-05        3.187377        3.382162             NaN              NaN
# 2021-02-04        3.254488        3.410848             NaN              NaN
# 2021-02-03        3.449778        3.407531             NaN              NaN
# 2021-02-02        3.253442        3.416015             NaN              NaN
# 2021-02-01        3.313240        3.719371             NaN              NaN
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2022-12-30              NaN              NaN
# 2022-12-29              NaN              NaN
# 2022-12-28              NaN              NaN
# 2022-12-27              NaN              NaN
# 2022-12-23              NaN              NaN
# ...                     ...              ...
# 2021-02-05              NaN              NaN
# 2021-02-04              NaN              NaN
# 2021-02-03              NaN              NaN
# 2021-02-02              NaN              NaN
# 2021-02-01              NaN              NaN
#
# [474 rows x 6 columns]

# %%
implied_vol_table_2yr.to_excel("output3.xlsx")

# %% [markdown]
# # 5 year Swap Dataframe

# %%
swap_5yr_merged=pd.merge(USS05,USS1m5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price_x':'5yr Swap'}, inplace = True)
swap_5yr_merged.rename(columns = {'Last Price_y':'1m Expiry'}, inplace = True)

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry
# Date
# 2023-04-19    3.4895   141.5000
# 2023-04-18    3.4729   137.7000
# 2023-04-17    3.4878   141.9000
# 2023-04-14    3.3861   137.3000
# 2023-04-13    3.2829   138.9000
# ...              ...        ...
# 2018-04-27    2.5250    50.6900
# 2018-04-26    2.5390    54.1110
# 2018-04-25    2.5640    57.4000
# 2018-04-24    2.5450    54.9393
# 2018-04-23    2.5380    55.1504
#
# [1266 rows x 2 columns]

# %%
swap_5yr_merged=pd.merge(swap_5yr_merged,USS3m5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price':'3m Expiry'}, inplace = True)

# %%
swap_5yr_merged=pd.merge(swap_5yr_merged,USS6m5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price':'6m Expiry'}, inplace = True)

# %%
swap_5yr_merged=pd.merge(swap_5yr_merged,USS1y5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price':'1yr Expiry'}, inplace = True)

# %%
swap_5yr_merged=pd.merge(swap_5yr_merged,USS2y5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price':'2yr Expiry'}, inplace = True)

# %%
swap_5yr_merged=pd.merge(swap_5yr_merged,USS5y5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price':'5yr Expiry'}, inplace = True)

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2023-04-19    3.4895   141.5000   134.5000   130.3000    124.0000    114.5000
# 2023-04-18    3.4729   137.7000   132.2000   127.5000    121.2000    112.8000
# 2023-04-17    3.4878   141.9000   134.9000   129.8000    122.0000    113.4000
# 2023-04-14    3.3861   137.3000   130.9000   125.8000    118.3000    111.1000
# 2023-04-13    3.2829   138.9000   134.6000   127.9000    118.5000    111.2000
# ...              ...        ...        ...        ...         ...         ...
# 2018-04-27    2.5250    50.6900    55.0835    58.5890     63.1965     68.8900
# 2018-04-26    2.5390    54.1110    56.9000    59.8854     64.7100     70.2500
# 2018-04-25    2.5640    57.4000    59.9385    62.0000     66.5550     71.7000
# 2018-04-24    2.5450    54.9393    57.9323    60.6574     65.3160     70.5000
# 2018-04-23    2.5380    55.1504    57.7513    60.4709     64.9855     70.3905
#
#             5yr Expiry
# Date
# 2023-04-19     96.3000
# 2023-04-18     95.6000
# 2023-04-17     95.7000
# 2023-04-14     95.1000
# 2023-04-13     95.4000
# ...                ...
# 2018-04-27     73.2087
# 2018-04-26     73.9000
# 2018-04-25     74.8075
# 2018-04-24     74.0000
# 2018-04-23     73.4171
#
# [1254 rows x 7 columns]

# %%
swap_5yr_merged=swap_5yr_merged.loc['2021-02-01':'2022-12-31']

# %%
fwd_rate=f = 2 * np.log(0.5 * (swap_5yr_merged["5yr Swap"]/100) + 1)*10000

# %%
swap_5yr_merged["Forward_Rate"] =fwd_rate

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    3.7420   128.0000   138.1000   138.7000    138.4000    132.8000
# 2022-12-29    3.7013   127.9000   136.4000   138.8000    137.4000    131.9000
# 2022-12-28    3.7295   128.1000   136.7000   138.9000    137.5000    131.7000
# 2022-12-27    3.6891   133.2000   135.6000   138.0000    136.3000    131.4000
# 2022-12-23    3.6290   120.4000   131.9000   134.1000    132.6000    128.6000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.4100    38.6500    38.9831    43.9752     49.9179     56.8511
# 2021-02-04    0.4020    38.3300    39.2225    43.2550     49.3653     56.3750
# 2021-02-03    0.3990    37.1100    39.0904    42.3750     48.2377     55.2400
# 2021-02-02    0.3740    36.5073    37.6815    41.9331     47.5513     55.1388
# 2021-02-01    0.3570    36.5488    36.3133    40.9738     47.0305     55.1066
#
#             5yr Expiry  Forward_Rate
# Date
# 2022-12-30    109.6000    370.742420
# 2022-12-29    108.5000    366.746772
# 2022-12-28    108.4000    369.515340
# 2022-12-27    107.8000    365.548904
# 2022-12-23    106.6000    359.646883
# ...                ...           ...
# 2021-02-05     63.9264     40.958032
# 2021-02-04     63.6707     40.159653
# 2021-02-03     63.2200     39.860253
# 2021-02-02     63.1738     37.365075
# 2021-02-01     63.0400     35.668176
#
# [480 rows x 8 columns]

# %%
swap_5yr_merged["1m5yr Annuity"] =annuity(5,1/12,swap_5yr_merged["Forward_Rate"])
swap_5yr_merged["3m5yr Annuity"] =annuity(5,3/12,swap_5yr_merged["Forward_Rate"])
swap_5yr_merged["6m5yr Annuity"] =annuity(5,1/2,swap_5yr_merged["Forward_Rate"])
swap_5yr_merged["1yr5yr Annuity"] =annuity(5,1,swap_5yr_merged["Forward_Rate"])
swap_5yr_merged["2yr5yr Annuity"] =annuity(5,2,swap_5yr_merged["Forward_Rate"])
swap_5yr_merged["5yr5yr Annuity"] =annuity(5,5,swap_5yr_merged["Forward_Rate"])

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    3.7420   128.0000   138.1000   138.7000    138.4000    132.8000
# 2022-12-29    3.7013   127.9000   136.4000   138.8000    137.4000    131.9000
# 2022-12-28    3.7295   128.1000   136.7000   138.9000    137.5000    131.7000
# 2022-12-27    3.6891   133.2000   135.6000   138.0000    136.3000    131.4000
# 2022-12-23    3.6290   120.4000   131.9000   134.1000    132.6000    128.6000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.4100    38.6500    38.9831    43.9752     49.9179     56.8511
# 2021-02-04    0.4020    38.3300    39.2225    43.2550     49.3653     56.3750
# 2021-02-03    0.3990    37.1100    39.0904    42.3750     48.2377     55.2400
# 2021-02-02    0.3740    36.5073    37.6815    41.9331     47.5513     55.1388
# 2021-02-01    0.3570    36.5488    36.3133    40.9738     47.0305     55.1066
#
#             5yr Expiry  Forward_Rate  1m5yr Annuity  3m5yr Annuity  \
# Date
# 2022-12-30    109.6000    370.742420       4.514778       4.500851
# 2022-12-29    108.5000    366.746772       4.519680       4.505888
# 2022-12-28    108.4000    369.515340       4.516283       4.502397
# 2022-12-27    107.8000    365.548904       4.521150       4.507399
# 2022-12-23    106.6000    359.646883       4.528406       4.514854
# ...                ...           ...            ...            ...
# 2021-02-05     63.9264     40.958032       4.943241       4.941554
# 2021-02-04     63.6707     40.159653       4.944339       4.942685
# 2021-02-03     63.2200     39.860253       4.944751       4.943109
# 2021-02-02     63.1738     37.365075       4.948187       4.946646
# 2021-02-01     63.0400     35.668176       4.950525       4.949054
#
#             6m5yr Annuity  1yr5yr Annuity  2yr5yr Annuity  5yr5yr Annuity
# Date
# 2022-12-30       4.480041        4.438709        4.357186        4.121492
# 2022-12-29       4.485278        4.444342        4.363588        4.130021
# 2022-12-28       4.481649        4.440438        4.359151        4.124109
# 2022-12-27       4.486850        4.446033        4.365509        4.132582
# 2022-12-23       4.494603        4.454372        4.374988        4.145224
# ...                   ...             ...             ...             ...
# 2021-02-05       4.939024        4.933970        4.923876        4.893718
# 2021-02-04       4.940204        4.935247        4.925347        4.895766
# 2021-02-03       4.940647        4.935726        4.925899        4.896534
# 2021-02-02       4.944337        4.939720        4.930500        4.902943
# 2021-02-01       4.946848        4.942439        4.933632        4.907307
#
# [480 rows x 14 columns]

# %%
swap_5yr_merged["1m5yr Premium"]=bachelier_call(0,1/12,swap_5yr_merged['1m Expiry']/10000,swap_5yr_merged['1m5yr Annuity'])*10000
swap_5yr_merged["3m5yr Premium"]=bachelier_call(0,3/12,swap_5yr_merged['3m Expiry']/10000,swap_5yr_merged['3m5yr Annuity'])*10000
swap_5yr_merged["6m5yr Premium"]=bachelier_call(0,1/2,swap_5yr_merged['6m Expiry']/10000,swap_5yr_merged['6m5yr Annuity'])*10000
swap_5yr_merged["1yr5yr Premium"]=bachelier_call(0,1,swap_5yr_merged['1yr Expiry']/10000,swap_5yr_merged['1yr5yr Annuity'])*10000
swap_5yr_merged["2yr5yr Premium"]=bachelier_call(0,2,swap_5yr_merged['2yr Expiry']/10000,swap_5yr_merged['2yr5yr Annuity'])*10000
swap_5yr_merged["5yr5yr Premium"]=bachelier_call(0,5,swap_5yr_merged['5yr Expiry']/10000,swap_5yr_merged['5yr5yr Annuity'])*10000

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2022-12-30    3.7420   128.0000   138.1000   138.7000    138.4000    132.8000
# 2022-12-29    3.7013   127.9000   136.4000   138.8000    137.4000    131.9000
# 2022-12-28    3.7295   128.1000   136.7000   138.9000    137.5000    131.7000
# 2022-12-27    3.6891   133.2000   135.6000   138.0000    136.3000    131.4000
# 2022-12-23    3.6290   120.4000   131.9000   134.1000    132.6000    128.6000
# ...              ...        ...        ...        ...         ...         ...
# 2021-02-05    0.4100    38.6500    38.9831    43.9752     49.9179     56.8511
# 2021-02-04    0.4020    38.3300    39.2225    43.2550     49.3653     56.3750
# 2021-02-03    0.3990    37.1100    39.0904    42.3750     48.2377     55.2400
# 2021-02-02    0.3740    36.5073    37.6815    41.9331     47.5513     55.1388
# 2021-02-01    0.3570    36.5488    36.3133    40.9738     47.0305     55.1066
#
#             5yr Expiry  Forward_Rate  1m5yr Annuity  3m5yr Annuity  \
# Date
# 2022-12-30    109.6000    370.742420       4.514778       4.500851
# 2022-12-29    108.5000    366.746772       4.519680       4.505888
# 2022-12-28    108.4000    369.515340       4.516283       4.502397
# 2022-12-27    107.8000    365.548904       4.521150       4.507399
# 2022-12-23    106.6000    359.646883       4.528406       4.514854
# ...                ...           ...            ...            ...
# 2021-02-05     63.9264     40.958032       4.943241       4.941554
# 2021-02-04     63.6707     40.159653       4.944339       4.942685
# 2021-02-03     63.2200     39.860253       4.944751       4.943109
# 2021-02-02     63.1738     37.365075       4.948187       4.946646
# 2021-02-01     63.0400     35.668176       4.950525       4.949054
#
#             6m5yr Annuity  1yr5yr Annuity  2yr5yr Annuity  5yr5yr Annuity  \
# Date
# 2022-12-30       4.480041        4.438709        4.357186        4.121492
# 2022-12-29       4.485278        4.444342        4.363588        4.130021
# 2022-12-28       4.481649        4.440438        4.359151        4.124109
# 2022-12-27       4.486850        4.446033        4.365509        4.132582
# 2022-12-23       4.494603        4.454372        4.374988        4.145224
# ...                   ...             ...             ...             ...
# 2021-02-05       4.939024        4.933970        4.923876        4.893718
# 2021-02-04       4.940204        4.935247        4.925347        4.895766
# 2021-02-03       4.940647        4.935726        4.925899        4.896534
# 2021-02-02       4.944337        4.939720        4.930500        4.902943
# 2021-02-01       4.946848        4.942439        4.933632        4.907307
#
#             1m5yr Premium  3m5yr Premium  6m5yr Premium  1yr5yr Premium  \
# Date
# 2022-12-30      66.552721     123.984785     175.288543      245.077179
# 2022-12-29      66.572925     122.595574     175.619984      243.615151
# 2022-12-28      66.626912     122.770034     175.604291      243.578310
# 2022-12-27      69.354177     121.917416     174.668944      241.756726
# 2022-12-23      62.790117     118.786920     170.025943      235.635174
# ...                   ...            ...            ...             ...
# 2021-02-05      22.002938      38.425538      61.269460       98.256851
# 2021-02-04      21.825616      38.670363      60.280421       97.194281
# 2021-02-03      21.132693      38.543431      59.059338       94.983392
# 2021-02-02      20.803924      37.180833      58.487096       93.707596
# 2021-02-01      20.837415      35.848251      57.178119       92.732283
#
#             2yr5yr Premium  5yr5yr Premium
# Date
# 2022-12-30      326.459482      402.958260
# 2022-12-29      324.723374      399.739516
# 2022-12-28      323.901354      398.799407
# 2022-12-27      323.634848      397.406804
# 2022-12-23      317.426316      394.185161
# ...                    ...             ...
# 2021-02-05      157.932318      279.070682
# 2021-02-04      156.656503      278.070767
# 2021-02-03      153.519729      276.145747
# 2021-02-02      153.381627      276.305110
# 2021-02-01      153.389435      275.965293
#
# [480 rows x 20 columns]

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][14]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,1/12,0,2))
implied_vol_table_5yr=pd.DataFrame({"1m Implied Vol":price},index=swap_5yr_merged.index)

# %%
implied_vol_table_5yr
# Out:
#             1m Implied Vol
# Date
# 2022-12-30        1.571649
# 2022-12-29        1.589110
# 2022-12-28        1.578554
# 2022-12-27        1.659759
# 2022-12-23        1.529695
# ...                    ...
# 2021-02-05        4.994875
# 2021-02-04        5.060594
# 2021-02-03        4.921600
# 2021-02-02        5.201107
# 2021-02-01        5.493607
#
# [480 rows x 1 columns]

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][15]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,3/12,0,2))
implied_vol_table_5yr["3m Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_5yr
# Out:
#             1m Implied Vol  3m Implied Vol
# Date
# 2022-12-30        1.571649        1.714200
# 2022-12-29        1.589110        1.713599
# 2022-12-28        1.578554        1.702463
# 2022-12-27        1.659759        1.709536
# 2022-12-23        1.529695        1.692305
# ...                    ...             ...
# 2021-02-05        4.994875        6.887860
# 2021-02-04        5.060594        7.466540
# 2021-02-03        4.921600        7.686896
# 2021-02-02        5.201107        8.673572
# 2021-02-01        5.493607        9.151513
#
# [480 rows x 2 columns]

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][16]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,1/2,0,0.5))
implied_vol_table_5yr["6m Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_5yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2022-12-30        1.571649        1.714200        1.767698         1.883305
# 2022-12-29        1.589110        1.713599        1.793654         1.898532
# 2022-12-28        1.578554        1.702463        1.778056         1.874044
# 2022-12-27        1.659759        1.709536        1.789314         1.885211
# 2022-12-23        1.529695        1.692305        1.768060         1.866461
# ...                    ...             ...             ...              ...
# 2021-02-05        4.994875        6.887860             NaN              NaN
# 2021-02-04        5.060594        7.466540             NaN              NaN
# 2021-02-03        4.921600        7.686896             NaN              NaN
# 2021-02-02        5.201107        8.673572             NaN              NaN
# 2021-02-01        5.493607        9.151513             NaN              NaN
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2022-12-30              NaN              NaN
# 2022-12-29              NaN              NaN
# 2022-12-28              NaN              NaN
# 2022-12-27              NaN              NaN
# 2022-12-23              NaN              NaN
# ...                     ...              ...
# 2021-02-05              NaN              NaN
# 2021-02-04              NaN              NaN
# 2021-02-03              NaN              NaN
# 2021-02-02              NaN              NaN
# 2021-02-01              NaN              NaN
#
# [480 rows x 6 columns]

# %%
implied_vol_table_5yr.to_excel("output2.xlsx")

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][17]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,1,0,4))
implied_vol_table_5yr["1yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: overflow encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][18]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,2,0,10))
implied_vol_table_5yr["2yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][19]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,5,0,15))
implied_vol_table_5yr["5yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_47861/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_5yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2022-12-30        1.571649        1.714200        1.767698         1.883305
# 2022-12-29        1.589110        1.713599        1.793654         1.898532
# 2022-12-28        1.578554        1.702463        1.778056         1.874044
# 2022-12-27        1.659759        1.709536        1.789314         1.885211
# 2022-12-23        1.529695        1.692305        1.768060         1.866461
# ...                    ...             ...             ...              ...
# 2021-02-05        4.994875        6.887860             NaN              NaN
# 2021-02-04        5.060594        7.466540             NaN              NaN
# 2021-02-03        4.921600        7.686896             NaN              NaN
# 2021-02-02        5.201107        8.673572             NaN              NaN
# 2021-02-01        5.493607        9.151513             NaN              NaN
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2022-12-30              NaN              NaN
# 2022-12-29              NaN              NaN
# 2022-12-28              NaN              NaN
# 2022-12-27              NaN              NaN
# 2022-12-23              NaN              NaN
# ...                     ...              ...
# 2021-02-05              NaN              NaN
# 2021-02-04              NaN              NaN
# 2021-02-03              NaN              NaN
# 2021-02-02              NaN              NaN
# 2021-02-01              NaN              NaN
#
# [480 rows x 6 columns]

# %%
implied_vol_table_5yr.to_excel("output2.xlsx")

# %%
plt.figure(figsize=(15, 10))
plt.plot(implied_vol_table_5yr.index, implied_vol_table_5yr['6m Implied Vol'], label = "implied vol")
#plt.plot(swap_30yr_merged.index, swap_30yr_merged['1m Expiry'], label = "realised vol")

# %%
plt.figure(figsize=(15, 10))
#plt.plot(implied_vol_table_30yr.index, implied_vol_table_30yr['1m Implied Vol'], label = "implied vol")
plt.plot(swap_5yr_merged.index, swap_5yr_merged['6m Expiry'], label = "realised vol")

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2020-01-31     1.105    75.9300    68.9950    67.3150     66.7950     67.0821
# 2020-01-30     1.194    72.0585    69.5869    67.4336     67.1463     66.7000
# 2020-01-29     1.197    68.6114    65.4223    64.5000     64.6300     65.9828
# 2020-01-28     1.257    68.3000    63.8425    63.4379     64.3549     65.1850
# 2020-01-27     1.220    66.5400    65.5247    64.8900     65.6112     66.8008
# ...              ...        ...        ...        ...         ...         ...
# 2018-04-27     2.525    50.6900    55.0835    58.5890     63.1965     68.8900
# 2018-04-26     2.539    54.1110    56.9000    59.8854     64.7100     70.2500
# 2018-04-25     2.564    57.4000    59.9385    62.0000     66.5550     71.7000
# 2018-04-24     2.545    54.9393    57.9323    60.6574     65.3160     70.5000
# 2018-04-23     2.538    55.1504    57.7513    60.4709     64.9855     70.3905
#
#             5yr Expiry  Forward_Rate  1m5yr Annuity  3m5yr Annuity  \
# Date
# 2020-01-31     66.8569    110.195863       4.849134       4.844683
# 2020-01-30     66.3200    119.045003       4.837271       4.832474
# 2020-01-29     65.8300    119.343221       4.836872       4.832064
# 2020-01-28     65.4200    125.306635       4.828899       4.823859
# 2020-01-27     66.5437    121.629406       4.833813       4.828916
# ...                ...           ...            ...            ...
# 2018-04-27     73.2087    250.919383       4.664771       4.655027
# 2018-04-26     73.9000    252.301881       4.663005       4.653211
# 2018-04-25     74.8075    254.770389       4.659852       4.649970
# 2018-04-24     74.0000    252.894351       4.662248       4.652433
# 2018-04-23     73.4171    252.203134       4.663131       4.653341
#
#             6m5yr Annuity  1yr5yr Annuity  2yr5yr Annuity  5yr5yr Annuity  \
# Date
# 2020-01-31       4.838014        4.824704        4.798194        4.719535
# 2020-01-30       4.825289        4.810949        4.782398        4.697758
# 2020-01-29       4.824860        4.810487        4.781867        4.697026
# 2020-01-28       4.816309        4.801245        4.771257        4.682414
# 2020-01-27       4.821580        4.806941        4.777796        4.691419
# ...                   ...             ...             ...             ...
# 2018-04-27       4.640450        4.611431        4.553938        4.385723
# 2018-04-26       4.638559        4.609393        4.551610        4.382572
# 2018-04-25       4.635185        4.605756        4.547458        4.376953
# 2018-04-24       4.637749        4.608520        4.550613        4.381223
# 2018-04-23       4.638694        4.609539        4.551776        4.382797
#
#             1m5yr Premium  3m5yr Premium  6m5yr Premium  1yr5yr Premium  \
# Date
# 2020-01-31      42.403043      66.675005      91.870075      128.565586
# 2020-01-30      40.142559      67.077538      91.789860      128.873295
# 2020-01-29      38.219084      63.057756      87.788887      124.031852
# 2020-01-28      37.982909      61.430569      86.190261      123.266628
# 2020-01-27      37.041800      63.115316      88.259651      125.822073
# ...                   ...            ...            ...             ...
# 2018-04-27      27.231532      51.147432      76.695738      116.262282
# 2018-04-26      29.058343      52.813515      78.360841      118.994037
# 2018-04-25      30.803744      55.595042      81.068812      122.290205
# 2018-04-24      29.498363      53.762684      79.357152      120.085645
# 2018-04-23      29.617316      53.605170      79.129279      119.504423
#
#             2yr5yr Premium  5yr5yr Premium
# Date
# 2020-01-31      181.597370      281.475453
# 2020-01-30      179.968563      277.926686
# 2020-01-29      178.013651      275.830261
# 2020-01-28      175.471087      273.259609
# 2020-01-27      180.067099      278.487821
# ...                    ...             ...
# 2018-04-27      176.997999      286.417094
# 2018-04-26      180.399970      288.913993
# 2018-04-25      183.955539      292.086882
# 2018-04-24      181.002302      289.215865
# 2018-04-23      180.767370      287.040816
#
# [446 rows x 20 columns]

# %%
implied_vol_table_5yr.to_excel("5 year Swap Vol table_thirdperiod.xlsx")

# %%
implied_vol_table_2yr.to_excel("2 year Swap Vol table_thirdperiod.xlsx")

# %%
implied_vol_table_5yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2022-12-30        1.571649        1.714200        1.767698         1.883305
# 2022-12-29        1.589110        1.713599        1.793654         1.898532
# 2022-12-28        1.578554        1.702463        1.778056         1.874044
# 2022-12-27        1.659759        1.709536        1.789314         1.885211
# 2022-12-23        1.529695        1.692305        1.768060         1.866461
# ...                    ...             ...             ...              ...
# 2021-02-05        4.994875        6.887860             NaN              NaN
# 2021-02-04        5.060594        7.466540             NaN              NaN
# 2021-02-03        4.921600        7.686896             NaN              NaN
# 2021-02-02        5.201107        8.673572             NaN              NaN
# 2021-02-01        5.493607        9.151513             NaN              NaN
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2022-12-30              NaN              NaN
# 2022-12-29              NaN              NaN
# 2022-12-28              NaN              NaN
# 2022-12-27              NaN              NaN
# 2022-12-23              NaN              NaN
# ...                     ...              ...
# 2021-02-05              NaN              NaN
# 2021-02-04              NaN              NaN
# 2021-02-03              NaN              NaN
# 2021-02-02              NaN              NaN
# 2021-02-01              NaN              NaN
#
# [480 rows x 6 columns]

# %%
implied_vol_table_1yr.to_excel("1 year Swap Vol table_thirdperiod.xlsx")
