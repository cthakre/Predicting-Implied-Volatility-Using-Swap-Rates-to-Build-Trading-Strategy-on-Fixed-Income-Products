# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm 
import os
from datetime import date
import datetime as dt
import scipy.stats as stats
import scipy
from scipy.optimize import root
import math

# %%
file_path = 'USS01.xlsx'
sheets_dict = pd.read_excel(file_path, sheet_name=None, parse_dates=['Date'], index_col='Date')
print(sheets_dict.keys())
# Out:
# dict_keys(['1yr Swap', '1m1yr', '3m1yr', '6m1yr', '1yr1yr', '2yr1yr', '5yr1yr'])

# %%
dfs = []
sheet_name = ['1yr Swap', '1m1yr', '3m1yr', '6m1yr', '1yr1yr', '2yr1yr', '5yr1yr']
for name in sheet_name:
    df = pd.DataFrame(sheets_dict[name])
    dfs.append(df)

# %%
USS01= dfs[0].iloc[1:, -1:]
USS1m1y = dfs[1].iloc[1:, -1:]
USS3m1y = dfs[2].iloc[1:, -1:]
USS6m1y = dfs[3].iloc[1:, -1:]
USS1y1y = dfs[4].iloc[1:, -1:]
USS2y1y = dfs[5].iloc[1:, -1:]
USS5y1y = dfs[6].iloc[1:, -1:]
USS01
# Out:
#              Close
# Date
# 2023-04-19  4.9243
# 2023-04-18  4.8878
# 2023-04-17  4.8776
# 2023-04-14  4.8184
# 2023-04-13  4.7038
# ...            ...
# 2018-04-27  2.1054
# 2018-04-26  2.1070
# 2018-04-25  2.1031
# 2018-04-24  2.0938
# 2018-04-23  2.0960
#
# [1294 rows x 1 columns]

# %%
file_path = 'USS02.xlsx'
sheets_dict = pd.read_excel(file_path, sheet_name=None, parse_dates=['Date'], index_col='Date')
print(sheets_dict.keys())
# Out:
# dict_keys(['2 yr Swap', '1m2yr', '3m2yr', '6m2yr', '1yr2yr', '2yr2yr', '5yr2yr'])

# %%
dfs = []
sheet_name = ['2 yr Swap', '1m2yr', '3m2yr', '6m2yr', '1yr2yr', '2yr2yr', '5yr2yr']
for name in sheet_name:
    df = pd.DataFrame(sheets_dict[name])
    dfs.append(df)

# %%
USS02= dfs[0].iloc[1:,:]
USS1m2y = dfs[1].iloc[1:-1:]
USS3m2y = dfs[2].iloc[1:,-1:]
USS6m2y = dfs[3].iloc[1:,-1:]
USS1y2y = dfs[4].iloc[1:,-1:]
USS2y2y = dfs[5].iloc[1:,-1:]
USS5y2y = dfs[6].iloc[1:,-1:]
USS1m2y
# Out:
#             Last Price
# Date
# 2023-04-19    166.4000
# 2023-04-18    165.1000
# 2023-04-17    169.2000
# 2023-04-14    167.2000
# 2023-04-13    169.2000
# ...                ...
# 2018-04-30     35.6000
# 2018-04-27     35.5000
# 2018-04-26     37.8000
# 2018-04-25     40.3593
# 2018-04-24     40.9500
#
# [1292 rows x 1 columns]

# %%
file_path = 'USS05.xlsx'
sheets_dict = pd.read_excel(file_path, sheet_name=None,parse_dates=['Date'], index_col='Date')
print(sheets_dict.keys())
# Out:
# dict_keys(['5 yr Swap', '1m5yr', '3m5yr', '6m5yr', '1yr5yr', '2yr5yr', '5yr5yr'])

# %%
dfs = []
sheet_name = ['5 yr Swap', '1m5yr', '3m5yr', '6m5yr', '1yr5yr', '2yr5yr', '5yr5yr']
for name in sheet_name:
    df = pd.DataFrame(sheets_dict[name])
    dfs.append(df)

# %%
USS05= dfs[0].iloc[1:,-1:]
USS1m5y = dfs[1].iloc[1:,-1:]
USS3m5y = dfs[2].iloc[1:,-1:]
USS6m5y = dfs[3].iloc[1:,-1:]
USS1y5y = dfs[4].iloc[1:,-1:]
USS2y5y = dfs[5].iloc[1:,-1:]
USS5y5y = dfs[6].iloc[1:,-1:]
USS05
# Out:
#             Last Price
# Date
# 2023-04-19      3.4895
# 2023-04-18      3.4729
# 2023-04-17      3.4878
# 2023-04-14      3.3861
# 2023-04-13      3.2829
# ...                ...
# 2018-04-27      2.5250
# 2018-04-26      2.5390
# 2018-04-25      2.5640
# 2018-04-24      2.5450
# 2018-04-23      2.5380
#
# [1292 rows x 1 columns]

# %%
file_path = 'USS010.xlsx'
sheets_dict = pd.read_excel(file_path, sheet_name=None, parse_dates=['Date'], index_col='Date')
print(sheets_dict.keys())
# Out:
# dict_keys(['10 yr Swap', '1m10yr', '3m10yr', '6m10yr', '1yr10yr', '2yr10yr', '5yr10yr'])

# %%
dfs = []
sheet_name = ['10 yr Swap', '1m10yr', '3m10yr', '6m10yr', '1yr10yr', '2yr10yr', '5yr10yr']
for name in sheet_name:
    df = pd.DataFrame(sheets_dict[name])
    dfs.append(df)

# %%
USS010= dfs[0].iloc[1:, -1:]
USS1m10y = dfs[1].iloc[1:, -1:]
USS3m10y = dfs[2].iloc[1:, -1:]
USS6m10y = dfs[3].iloc[1:, -1:]
USS1y10y = dfs[4].iloc[1:, -1:]
USS2y10y = dfs[5].iloc[1:, -1:]
USS5y10y = dfs[6].iloc[1:, -1:]
USS010
# Out:
#              Close
# Date
# 2023-04-19  3.2934
# 2023-04-18  3.2870
# 2023-04-17  3.3010
# 2023-04-14  3.2080
# 2023-04-13  3.1390
# ...            ...
# 2018-04-27  2.5700
# 2018-04-26  2.5950
# 2018-04-25  2.6380
# 2018-04-24  2.6070
# 2018-04-23  2.5850
#
# [1292 rows x 1 columns]

# %%
file_path = 'USS030.xlsx'
sheets_dict = pd.read_excel(file_path, sheet_name=None, parse_dates=['Date'], index_col='Date')
print(sheets_dict.keys())
# Out:
# dict_keys(['30yr Swap', '1m30yr', '3m30yr', '6m30yr', '1yr30yr', '2yr30yr', '5yr30yr'])

# %%
dfs = []
sheet_name = ['30yr Swap', '1m30yr', '3m30yr', '6m30yr', '1yr30yr', '2yr30yr', '5yr30yr']
for name in sheet_name:
    df = pd.DataFrame(sheets_dict[name])
    dfs.append(df)

# %%
USS030= dfs[0].iloc[1:, -1:]
USS1m30y = dfs[1].iloc[1:, -1:]
USS3m30y = dfs[2].iloc[1:, -1:]
USS6m30y = dfs[3].iloc[1:, -1:]
USS1y30y = dfs[4].iloc[1:, -1:]
USS2y30y = dfs[5].iloc[1:, -1:]
USS5y30y = dfs[6].iloc[1:, -1:]
USS030
# Out:
#              Close
# Date
# 2023-04-19  3.0584
# 2023-04-18  3.0630
# 2023-04-17  3.0735
# 2023-04-14  2.9925
# 2023-04-13  2.9440
# ...            ...
# 2018-04-27  2.5380
# 2018-04-26  2.5690
# 2018-04-25  2.6040
# 2018-04-24  2.5710
# 2018-04-23  2.5380
#
# [1295 rows x 1 columns]

# %%
swap_merged=pd.merge(USS01,USS02,how='inner',on='Date')
swap_merged=pd.merge(swap_merged,USS05,how='inner',on='Date')
swap_merged=pd.merge(swap_merged,USS010,how='inner',on='Date')
swap_merged=pd.merge(swap_merged,USS030,how='inner',on='Date')

# %%
swap_merged
# Out:
#             Close_x  Last Price_x  Last Price_y  Close_y   Close
# Date
# 2023-04-19   4.9243        4.2539        3.4895   3.2934  3.0584
# 2023-04-18   4.8878        4.2070        3.4729   3.2870  3.0630
# 2023-04-17   4.8776        4.2115        3.4878   3.3010  3.0735
# 2023-04-14   4.8184        4.1120        3.3861   3.2080  2.9925
# 2023-04-13   4.7038        3.9815        3.2829   3.1390  2.9440
# ...             ...           ...           ...      ...     ...
# 2018-04-27   2.1054        2.3380        2.5250   2.5700  2.5380
# 2018-04-26   2.1070        2.3383        2.5390   2.5950  2.5690
# 2018-04-25   2.1031        2.3411        2.5640   2.6380  2.6040
# 2018-04-24   2.0938        2.3366        2.5450   2.6070  2.5710
# 2018-04-23   2.0960        2.3410        2.5380   2.5850  2.5380
#
# [1288 rows x 5 columns]

# %%
plt.figure(figsize=(15, 10))
plt.plot(swap_merged.index, swap_merged['Close_x'], label = "USS01")
plt.plot(swap_merged.index, swap_merged['Last Price_x'], label = "USS02")
plt.plot(swap_merged.index, swap_merged['Last Price_y'], label = "USS05")
plt.plot(swap_merged.index, swap_merged['Close_y'], label = "USS010")
plt.plot(swap_merged.index, swap_merged['Close'], label = "USS030")
plt.legend()

# %%
swaption_merged_1m=pd.merge(USS1m1y,USS1m2y,how='inner',on='Date')
swaption_merged_1m=pd.merge(swaption_merged_1m,USS1m5y,how='inner',on='Date')
swaption_merged_1m=pd.merge(swaption_merged_1m,USS1m10y,how='inner',on='Date')
swaption_merged_1m=pd.merge(swaption_merged_1m,USS1m30y,how='inner',on='Date')

# %%
plt.figure(figsize=(15, 10))
plt.plot(swaption_merged_1m.index, swaption_merged_1m['Close_x'], label = "USS1m1y")
plt.plot(swaption_merged_1m.index, swaption_merged_1m['Last Price_x'], label = "USS1m2y")
plt.plot(swaption_merged_1m.index, swaption_merged_1m['Last Price_y'], label = "USS1m5y")
plt.plot(swaption_merged_1m.index, swaption_merged_1m['Close_y'], label = "USS1m10y")
plt.plot(swaption_merged_1m.index, swaption_merged_1m['Close'], label = "USS1m30y")
plt.legend()

# %% [markdown]
# ## 1 YEAR SWAP DATA FRAME

# %%
swap_1yr_merged=pd.merge(USS01,USS1m1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close_x':'1yr Swap'}, inplace = True)
swap_1yr_merged.rename(columns = {'Close_y':'1m Expiry'}, inplace = True)

# %%
swap_1yr_merged=pd.merge(swap_1yr_merged,USS3m1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close':'3m Expiry'}, inplace = True)

# %%
swap_1yr_merged=pd.merge(swap_1yr_merged,USS6m1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close':'6m Expiry'}, inplace = True)

# %%
swap_1yr_merged=pd.merge(swap_1yr_merged,USS1y1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close':'1yr Expiry'}, inplace = True)

# %%
swap_1yr_merged=pd.merge(swap_1yr_merged,USS2y1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close':'2yr Expiry'}, inplace = True)

# %%
swap_1yr_merged=pd.merge(swap_1yr_merged,USS5y1y,how='inner',on='Date')
swap_1yr_merged.rename(columns = {'Close':'5yr Expiry'}, inplace = True)

# %%
swap_1yr_merged
# Out:
#             1yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2023-04-19    4.9243   153.3449   153.0000   153.2000    153.9000    136.9000
# 2023-04-18    4.8878   153.5600   151.4000   151.8000    152.8000    135.5000
# 2023-04-17    4.8776   154.9750   154.2000   154.2000    150.9000    135.2000
# 2023-04-14    4.8184   160.5883   154.7000   154.5000    149.6000    132.3000
# 2023-04-13    4.7038   166.3000   160.9000   161.2000    153.0000    134.1000
# ...              ...        ...        ...        ...         ...         ...
# 2018-04-27    2.1054    26.6248    32.1073    37.4925     46.7418     62.5986
# 2018-04-26    2.1070    27.9066    34.0906    39.6118     47.5000     63.4476
# 2018-04-25    2.1031    30.1568    35.3982    40.8817     49.6592     64.4074
# 2018-04-24    2.0938    29.9912    34.9173    40.2930     48.8168     63.9111
# 2018-04-23    2.0960    30.8623    36.0257    40.6542     49.3488     63.2212
#
#             5yr Expiry
# Date
# 2023-04-19    106.6000
# 2023-04-18    106.0000
# 2023-04-17    106.2000
# 2023-04-14    105.7000
# 2023-04-13    105.6000
# ...                ...
# 2018-04-27     75.7315
# 2018-04-26     76.8627
# 2018-04-25     77.0243
# 2018-04-24     76.5127
# 2018-04-23     75.4768
#
# [1283 rows x 7 columns]

# %%
swap_1yr_merged=swap_1yr_merged.loc['2020-01-31':'2021-01-31']

# %%
swap_1yr_merged
# Out:
#             1yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29    0.0700    10.5986     9.6837    11.5899     17.0462     29.6685
# 2021-01-28    0.0730    11.0450    10.4899    10.9400     16.5500     29.6032
# 2021-01-27    0.0710    10.1861     9.3711    10.2392     16.1106     28.2932
# 2021-01-26    0.0710    11.0367    10.4942    11.4464     16.0454     28.2981
# 2021-01-25    0.0667    11.0466    10.5005    11.4421     15.9801     28.3118
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06    1.4450    40.6709    44.1804    49.2203     56.9339     62.1588
# 2020-02-05    1.4459    41.8743    45.2468    48.9018     56.8662     62.4407
# 2020-02-04    1.4223    43.8214    48.4973    50.8080     56.6884     62.6927
# 2020-02-03    1.3770    45.0741    53.7778    56.3858     61.2162     64.0800
# 2020-01-31    1.3330    42.0101    49.7294    53.7102     61.7586     65.5825
#
#             5yr Expiry
# Date
# 2021-01-29     59.3572
# 2021-01-28     59.2170
# 2021-01-27     58.8136
# 2021-01-26     58.7101
# 2021-01-25     59.2994
# ...                ...
# 2020-02-06     65.8519
# 2020-02-05     66.4330
# 2020-02-04     67.4893
# 2020-02-03     68.3524
# 2020-01-31     68.1095
#
# [261 rows x 7 columns]

# %%
fwd_rate= 2 * np.log(0.5 * (swap_1yr_merged["1yr Swap"]/100) + 1)*10000

# %%
swap_1yr_merged["Forward_Rate"] =fwd_rate

# %%
swap_1yr_merged
# Out:
#             1yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29    0.0700    10.5986     9.6837    11.5899     17.0462     29.6685
# 2021-01-28    0.0730    11.0450    10.4899    10.9400     16.5500     29.6032
# 2021-01-27    0.0710    10.1861     9.3711    10.2392     16.1106     28.2932
# 2021-01-26    0.0710    11.0367    10.4942    11.4464     16.0454     28.2981
# 2021-01-25    0.0667    11.0466    10.5005    11.4421     15.9801     28.3118
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06    1.4450    40.6709    44.1804    49.2203     56.9339     62.1588
# 2020-02-05    1.4459    41.8743    45.2468    48.9018     56.8662     62.4407
# 2020-02-04    1.4223    43.8214    48.4973    50.8080     56.6884     62.6927
# 2020-02-03    1.3770    45.0741    53.7778    56.3858     61.2162     64.0800
# 2020-01-31    1.3330    42.0101    49.7294    53.7102     61.7586     65.5825
#
#             5yr Expiry  Forward_Rate
# Date
# 2021-01-29     59.3572      6.998775
# 2021-01-28     59.2170      7.298668
# 2021-01-27     58.8136      7.098740
# 2021-01-26     58.7101      7.098740
# 2021-01-25     59.2994      6.668888
# ...                ...           ...
# 2020-02-06     65.8519    143.980495
# 2020-02-05     66.4330    144.069849
# 2020-02-04     67.4893    141.726651
# 2020-02-03     68.3524    137.228132
# 2020-01-31     68.1095    132.857742
#
# [261 rows x 8 columns]

# %%
expiry=[1/12,3/12,1/2,1,2,5]

# %%
def annuity(tenor, expiry,forward_array):
    
    annuity_list = np.zeros(len(forward_array))
    for i in range(1,(tenor*2)+1):
        #print(i)
        
        #print(forward_array)
        annuity_list += 0.5 * np.exp(-0.5*( expiry+ i) * (forward_array/10000))
        #print(annuity_list)
    return annuity_list

# %%
swap_1yr_merged["1m1yr Annuity"] =annuity(1,1/12,swap_1yr_merged["Forward_Rate"])
swap_1yr_merged["3m1yr Annuity"] =annuity(1,3/12,swap_1yr_merged["Forward_Rate"])
swap_1yr_merged["6m1yr Annuity"] =annuity(1,1/2,swap_1yr_merged["Forward_Rate"])
swap_1yr_merged["1yr1yr Annuity"] =annuity(1,1,swap_1yr_merged["Forward_Rate"])
swap_1yr_merged["2yr1yr Annuity"] =annuity(1,2,swap_1yr_merged["Forward_Rate"])
swap_1yr_merged["5yr1yr Annuity"] =annuity(1,5,swap_1yr_merged["Forward_Rate"])

# %%
swap_1yr_merged
# Out:
#             1yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29    0.0700    10.5986     9.6837    11.5899     17.0462     29.6685
# 2021-01-28    0.0730    11.0450    10.4899    10.9400     16.5500     29.6032
# 2021-01-27    0.0710    10.1861     9.3711    10.2392     16.1106     28.2932
# 2021-01-26    0.0710    11.0367    10.4942    11.4464     16.0454     28.2981
# 2021-01-25    0.0667    11.0466    10.5005    11.4421     15.9801     28.3118
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06    1.4450    40.6709    44.1804    49.2203     56.9339     62.1588
# 2020-02-05    1.4459    41.8743    45.2468    48.9018     56.8662     62.4407
# 2020-02-04    1.4223    43.8214    48.4973    50.8080     56.6884     62.6927
# 2020-02-03    1.3770    45.0741    53.7778    56.3858     61.2162     64.0800
# 2020-01-31    1.3330    42.0101    49.7294    53.7102     61.7586     65.5825
#
#             5yr Expiry  Forward_Rate  1m1yr Annuity  3m1yr Annuity  \
# Date
# 2021-01-29     59.3572      6.998775       0.999446       0.999388
# 2021-01-28     59.2170      7.298668       0.999422       0.999362
# 2021-01-27     58.8136      7.098740       0.999438       0.999379
# 2021-01-26     58.7101      7.098740       0.999438       0.999379
# 2021-01-25     59.2994      6.668888       0.999472       0.999417
# ...                ...           ...            ...            ...
# 2020-02-06     65.8519    143.980495       0.988673       0.987487
# 2020-02-05     66.4330    144.069849       0.988666       0.987479
# 2020-02-04     67.4893    141.726651       0.988849       0.987682
# 2020-02-03     68.3524    137.228132       0.989201       0.988070
# 2020-01-31     68.1095    132.857742       0.989543       0.988448
#
#             6m1yr Annuity  1yr1yr Annuity  2yr1yr Annuity  5yr1yr Annuity
# Date
# 2021-01-29       0.999300        0.999126        0.998776        0.997728
# 2021-01-28       0.999270        0.999088        0.998724        0.997631
# 2021-01-27       0.999290        0.999113        0.998759        0.997696
# 2021-01-26       0.999290        0.999113        0.998759        0.997696
# 2021-01-25       0.999333        0.999167        0.998834        0.997835
# ...                   ...             ...             ...             ...
# 2020-02-06       0.985711        0.982170        0.975125        0.954290
# 2020-02-05       0.985703        0.982159        0.975109        0.954263
# 2020-02-04       0.985933        0.982446        0.975509        0.954990
# 2020-02-03       0.986377        0.982999        0.976277        0.956386
# 2020-01-31       0.986808        0.983535        0.977023        0.957745
#
# [261 rows x 14 columns]

# %%
def bachelier_call(strike_premium,T,sigma,A):
    
    d1=strike_premium/ (sigma* math.sqrt(T))
    P= A*sigma*math.sqrt(T)*((d1*norm.cdf(d1))+norm.pdf(d1))    
    return P

# %%
swap_1yr_merged["1m1yr Premium"]=bachelier_call(0,1/12,swap_1yr_merged['1m Expiry']/10000,swap_1yr_merged['1m1yr Annuity'])*10000
swap_1yr_merged["3m1yr Premium"]=bachelier_call(0,3/12,swap_1yr_merged['3m Expiry']/10000,swap_1yr_merged['3m1yr Annuity'])*10000
swap_1yr_merged["6m1yr Premium"]=bachelier_call(0,1/2,swap_1yr_merged['6m Expiry']/10000,swap_1yr_merged['6m1yr Annuity'])*10000
swap_1yr_merged["1yr1yr Premium"]=bachelier_call(0,1,swap_1yr_merged['1yr Expiry']/10000,swap_1yr_merged['1yr1yr Annuity'])*10000
swap_1yr_merged["2yr1yr Premium"]=bachelier_call(0,2,swap_1yr_merged['2yr Expiry']/10000,swap_1yr_merged['2yr1yr Annuity'])*10000
swap_1yr_merged["5yr1yr Premium"]=bachelier_call(0,5,swap_1yr_merged['5yr Expiry']/10000,swap_1yr_merged['5yr1yr Annuity'])*10000

# %%
swap_1yr_merged
# Out:
#             1yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29    0.0700    10.5986     9.6837    11.5899     17.0462     29.6685
# 2021-01-28    0.0730    11.0450    10.4899    10.9400     16.5500     29.6032
# 2021-01-27    0.0710    10.1861     9.3711    10.2392     16.1106     28.2932
# 2021-01-26    0.0710    11.0367    10.4942    11.4464     16.0454     28.2981
# 2021-01-25    0.0667    11.0466    10.5005    11.4421     15.9801     28.3118
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06    1.4450    40.6709    44.1804    49.2203     56.9339     62.1588
# 2020-02-05    1.4459    41.8743    45.2468    48.9018     56.8662     62.4407
# 2020-02-04    1.4223    43.8214    48.4973    50.8080     56.6884     62.6927
# 2020-02-03    1.3770    45.0741    53.7778    56.3858     61.2162     64.0800
# 2020-01-31    1.3330    42.0101    49.7294    53.7102     61.7586     65.5825
#
#             5yr Expiry  Forward_Rate  1m1yr Annuity  3m1yr Annuity  \
# Date
# 2021-01-29     59.3572      6.998775       0.999446       0.999388
# 2021-01-28     59.2170      7.298668       0.999422       0.999362
# 2021-01-27     58.8136      7.098740       0.999438       0.999379
# 2021-01-26     58.7101      7.098740       0.999438       0.999379
# 2021-01-25     59.2994      6.668888       0.999472       0.999417
# ...                ...           ...            ...            ...
# 2020-02-06     65.8519    143.980495       0.988673       0.987487
# 2020-02-05     66.4330    144.069849       0.988666       0.987479
# 2020-02-04     67.4893    141.726651       0.988849       0.987682
# 2020-02-03     68.3524    137.228132       0.989201       0.988070
# 2020-01-31     68.1095    132.857742       0.989543       0.988448
#
#             6m1yr Annuity  1yr1yr Annuity  2yr1yr Annuity  5yr1yr Annuity  \
# Date
# 2021-01-29       0.999300        0.999126        0.998776        0.997728
# 2021-01-28       0.999270        0.999088        0.998724        0.997631
# 2021-01-27       0.999290        0.999113        0.998759        0.997696
# 2021-01-26       0.999290        0.999113        0.998759        0.997696
# 2021-01-25       0.999333        0.999167        0.998834        0.997835
# ...                   ...             ...             ...             ...
# 2020-02-06       0.985711        0.982170        0.975125        0.954290
# 2020-02-05       0.985703        0.982159        0.975109        0.954263
# 2020-02-04       0.985933        0.982446        0.975509        0.954990
# 2020-02-03       0.986377        0.982999        0.976277        0.956386
# 2020-01-31       0.986808        0.983535        0.977023        0.957745
#
#             1m1yr Premium  3m1yr Premium  6m1yr Premium  1yr1yr Premium  \
# Date
# 2021-01-29       1.219909       1.930436       3.267163        6.794503
# 2021-01-28       1.271260       2.091096       3.083865        6.596474
# 2021-01-27       1.172420       1.868103       2.886375        6.421499
# 2021-01-26       1.270324       2.091990       3.226679        6.395511
# 2021-01-25       1.271507       2.093325       3.225605        6.369825
# ...                   ...            ...            ...             ...
# 2020-02-06       4.630797       8.702442      13.686397       22.308356
# 2020-02-05       4.767783       8.912427      13.597713       22.281581
# 2020-02-04       4.990403       9.554647      14.131061       22.218416
# 2020-02-03       5.134888      10.599146      15.689447       24.006526
# 2020-01-31       4.787488       9.804986      14.951484       24.232459
#
#             2yr1yr Premium  5yr1yr Premium
# Date
# 2021-01-29       16.718170       52.830003
# 2021-01-28       16.680498       52.700083
# 2021-01-27       15.942911       52.344479
# 2021-01-26       15.945672       52.252363
# 2021-01-25       15.954592       52.784218
# ...                    ...             ...
# 2020-02-06       34.196980       56.058821
# 2020-02-05       34.351532       56.551862
# 2020-02-04       34.504308       57.494806
# 2020-02-03       35.295600       58.315262
# 2020-01-31       36.150810       58.190603
#
# [261 rows x 20 columns]

# %%
swap_1yr_merged.to_excel("output1.xlsx")

# %%
import numpy as np
from scipy.stats import norm

N_prime = norm.pdf
N = norm.cdf


def black_scholes_call(S, K, T, r, sigma):
    '''

    :param S: Asset price
    :param K: Strike price
    :param T: Time to maturity
    :param r: risk-free rate (treasury bills)
    :param sigma: volatility
    :return: call price
    '''

    ###standard black-scholes formula
    d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)

    call = S * N(d1) -  N(d2)* K * np.exp(-r * T)
    return call

def vega(S, K, T, r, sigma):
    '''

    :param S: Asset price
    :param K: Strike price
    :param T: Time to Maturity
    :param r: risk-free rate (treasury bills)
    :param sigma: volatility
    :return: partial derivative w.r.t volatility
    '''

    ### calculating d1 from black scholes
    d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

    #see hull derivatives chapter on greeks for reference
    vega = S * N_prime(d1) * np.sqrt(T)
    return vega



def implied_volatility_call(C, S, K, T, r,sig, tol=0.0001,
                            max_iterations=500):
    '''

    :param C: Observed call price
    :param S: Asset price
    :param K: Strike Price
    :param T: Time to Maturity
    :param r: riskfree rate
    :param tol: error tolerance in result
    :param max_iterations: max iterations to update vol
    :return: implied volatility in percent
    '''


    ### assigning initial volatility estimate for input in Newton_rap procedure
    sigma = sig
    
    for i in range(max_iterations):

        ### calculate difference between blackscholes price and market price with
        ### iteratively updated volality estimate
        diff = black_scholes_call(S, K, T, r, sigma) - C

        ###break if difference is less than specified tolerance level
        if abs(diff) < tol:
            #print(f'found on {i}th iteration')
            #print(f'difference is equal to {diff}')
            break

        ### use newton rapshon to update the estimate
        sigma = sigma - diff / vega(S, K, T, r, sigma)

    return sigma

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][14]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,1/12,0,0.1))
implied_vol_table_1yr=pd.DataFrame({"1m Implied Vol":price},index=swap_1yr_merged.index)
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_1yr.to_excel("output3.xlsx")

# %%
implied_vol_table_1yr
#implied_vol_table_1yr.max()
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2021-01-29        1.513252        1.382574        1.692754         2.907656
# 2021-01-28        1.512144        1.436092        1.100000         2.685111
# 2021-01-27        1.433860        1.319088        1.100000         2.687800
# 2021-01-26        1.553596        1.477176        1.648407         2.675646
# 2021-01-25        1.655292        1.573409        1.753667         2.855697
# ...                    ...             ...             ...              ...
# 2020-02-06        0.278275        0.301935        0.348800         0.388225
# 2020-02-05        0.286328        0.309028        0.346371         0.387508
# 2020-02-04        0.304670        0.336793        0.365555         0.392897
# 2020-02-03        0.323804        0.385900        0.418247         0.439281
# 2020-01-31        0.311862        0.368770        0.411834         0.458428
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2021-01-29              NaN              NaN
# 2021-01-28              NaN              NaN
# 2021-01-27              NaN              NaN
# 2021-01-26              NaN              NaN
# 2021-01-25              NaN              NaN
# ...                     ...              ...
# 2020-02-06              NaN              NaN
# 2020-02-05              NaN              NaN
# 2020-02-04              NaN              NaN
# 2020-02-03              NaN              NaN
# 2020-01-31              NaN              NaN
#
# [261 rows x 6 columns]

# %%
implied_vol_table_1yr.max()
# Out:
# 1m Implied Vol    14.599725
# dtype: float64

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][15]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,3/12,0,0.3))
implied_vol_table_1yr["3m Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_1yr.to_excel("output3.xlsx")

# %%
implied_vol_table_1yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2021-01-29        1.513252        1.383010        1.692754         2.907656
# 2021-01-28        1.512144        1.436536        1.100000         2.685111
# 2021-01-27        1.433860        1.319514        1.100000         2.687800
# 2021-01-26        1.553596        1.477627        1.648407         2.675646
# 2021-01-25        1.655292        1.573874        1.753667         2.855697
# ...                    ...             ...             ...              ...
# 2020-02-06        0.278275        0.300000        0.348800         0.388225
# 2020-02-05        0.286328        0.300000        0.346371         0.387508
# 2020-02-04        0.304670        0.337065        0.365555         0.392897
# 2020-02-03        0.323804        0.386180        0.418247         0.439281
# 2020-01-31        0.311862        0.369047        0.411834         0.458428
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2021-01-29              NaN              NaN
# 2021-01-28              NaN              NaN
# 2021-01-27              NaN              NaN
# 2021-01-26              NaN              NaN
# 2021-01-25              NaN              NaN
# ...                     ...              ...
# 2020-02-06              NaN              NaN
# 2020-02-05              NaN              NaN
# 2020-02-04              NaN              NaN
# 2020-02-03              NaN              NaN
# 2020-01-31              NaN              NaN
#
# [261 rows x 6 columns]

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][16]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,1/2,0,1.1))
implied_vol_table_1yr["6m Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][17]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,1,0,1.5))
implied_vol_table_1yr["1yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][18]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,2,0,1.5))
implied_vol_table_1yr["2yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: overflow encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_1yr_merged['1yr Swap'])):    
    price.append(implied_volatility_call(swap_1yr_merged.iloc[i][19]/10000,swap_1yr_merged.iloc[i][0]/100,swap_1yr_merged.iloc[i][0]/100,5,0,15))
implied_vol_table_1yr["5yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_1yr.to_excel("output3.xlsx")

# %%
implied_vol_table_1yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2021-01-29        1.513252        1.382574        1.692754         2.907656
# 2021-01-28        1.512144        1.436092        1.100000         2.685111
# 2021-01-27        1.433860        1.319088        1.100000         2.687800
# 2021-01-26        1.553596        1.477176        1.648407         2.675646
# 2021-01-25        1.655292        1.573409        1.753667         2.855697
# ...                    ...             ...             ...              ...
# 2020-02-06        0.278275        0.301935        0.348800         0.388225
# 2020-02-05        0.286328        0.309028        0.346371         0.387508
# 2020-02-04        0.304670        0.336793        0.365555         0.392897
# 2020-02-03        0.323804        0.385900        0.418247         0.439281
# 2020-01-31        0.311862        0.368770        0.411834         0.458428
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2021-01-29              NaN              NaN
# 2021-01-28              NaN              NaN
# 2021-01-27              NaN              NaN
# 2021-01-26              NaN              NaN
# 2021-01-25              NaN              NaN
# ...                     ...              ...
# 2020-02-06              NaN              NaN
# 2020-02-05              NaN              NaN
# 2020-02-04              NaN              NaN
# 2020-02-03              NaN              NaN
# 2020-01-31              NaN              NaN
#
# [261 rows x 6 columns]

# %% [markdown]
# ## 2 yr Swap Data Frame

# %%
swap_2yr_merged=pd.merge(USS02,USS1m2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price_x':'2yr Swap'}, inplace = True)
swap_2yr_merged.rename(columns = {'Last Price_y':'1m Expiry'}, inplace = True)

# %%
swap_2yr_merged=pd.merge(swap_2yr_merged,USS3m2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price':'3m Expiry'}, inplace = True)

# %%
swap_2yr_merged=pd.merge(swap_2yr_merged,USS6m2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price':'6m Expiry'}, inplace = True)

# %%
swap_2yr_merged=pd.merge(swap_2yr_merged,USS1y2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price':'1yr Expiry'}, inplace = True)

# %%
swap_2yr_merged=pd.merge(swap_2yr_merged,USS2y2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price':'2yr Expiry'}, inplace = True)

# %%
swap_2yr_merged=pd.merge(swap_2yr_merged,USS5y2y,how='inner',on='Date')
swap_2yr_merged.rename(columns = {'Last Price':'5yr Expiry'}, inplace = True)

# %%
swap_2yr_merged
# Out:
#             2yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2023-04-19    4.2539   166.4000   157.8000   152.4000    144.9000    129.8000
# 2023-04-18    4.2070   165.1000   156.8000   150.7000    143.2000    128.5000
# 2023-04-17    4.2115   169.2000   159.7000   153.4000    142.9000    129.1000
# 2023-04-14    4.1120   167.2000   156.8000   150.4000    140.4000    127.2000
# 2023-04-13    3.9815   169.2000   163.2000   155.2000    143.0000    128.7000
# ...              ...        ...        ...        ...         ...         ...
# 2018-04-30    2.3440    35.6000    41.4143    47.0193     54.0398     65.5770
# 2018-04-27    2.3380    35.5000    43.8338    47.4723     54.4642     66.1209
# 2018-04-26    2.3383    37.8000    44.5189    48.8846     55.8512     66.8327
# 2018-04-25    2.3411    40.3593    46.4432    50.5287     57.7373     67.7000
# 2018-04-24    2.3366    40.9500    45.8284    49.6994     56.5584     67.0000
#
#             5yr Expiry
# Date
# 2023-04-19    103.0000
# 2023-04-18    102.3000
# 2023-04-17    102.5000
# 2023-04-14    101.9000
# 2023-04-13    102.2000
# ...                ...
# 2018-04-30     74.4516
# 2018-04-27     75.0327
# 2018-04-26     75.7000
# 2018-04-25     76.4000
# 2018-04-24     75.7000
#
# [1255 rows x 7 columns]

# %%
swap_2yr_merged.to_excel("2 year Swap Merged.xlsx")

# %%
swap_2yr_merged=swap_2yr_merged.loc['2020-01-31':'2021-01-31']

# %%
fwd_rate=f = 2 * np.log(0.5 * (swap_2yr_merged["2yr Swap"]/100) + 1)*10000

# %%
swap_2yr_merged["Forward_Rate"] =fwd_rate

# %%
swap_2yr_merged
# Out:
#             2yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29    0.0732     12.650    13.5668    16.9330     23.8020     38.8012
# 2021-01-28    0.0790     12.110    13.4767    16.6400     23.5950     38.2134
# 2021-01-27    0.0749     11.020    13.3201    16.4322     22.9946     37.5097
# 2021-01-26    0.0745     12.475    13.3633    16.9350     22.8690     37.3400
# 2021-01-25    0.0718     11.885    13.3430    17.2400     22.9350     37.8312
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06    1.3171     56.540    54.9493    57.8200     60.2395     63.1054
# 2020-02-05    1.3142     58.790    57.4622    58.5000     60.6495     63.3408
# 2020-02-04    1.2800     62.080    58.9966    58.9465     61.6259     64.0755
# 2020-02-03    1.2170     67.580    63.4823    62.8350     65.0052     65.9400
# 2020-01-31    1.1712     57.150    61.9829    60.0300     65.0545     66.8200
#
#             5yr Expiry  Forward_Rate
# Date
# 2021-01-29     60.1250      7.318661
# 2021-01-28     59.9200      7.898440
# 2021-01-27     59.6146      7.488598
# 2021-01-26     59.9083      7.448613
# 2021-01-25     60.5757      7.178711
# ...                ...           ...
# 2020-02-06     65.6474    131.278207
# 2020-02-05     65.8377    130.990102
# 2020-02-04     66.6980    127.592139
# 2020-02-03     67.6501    121.331223
# 2020-01-31     67.4369    116.778406
#
# [252 rows x 8 columns]

# %%
swap_2yr_merged["1m2yr Annuity"] =annuity(2,1/12,swap_2yr_merged["Forward_Rate"])
swap_2yr_merged["3m2yr Annuity"] =annuity(2,3/12,swap_2yr_merged["Forward_Rate"])
swap_2yr_merged["6m2yr Annuity"] =annuity(2,1/2,swap_2yr_merged["Forward_Rate"])
swap_2yr_merged["1yr2yr Annuity"] =annuity(2,1,swap_2yr_merged["Forward_Rate"])
swap_2yr_merged["2yr2yr Annuity"] =annuity(2,2,swap_2yr_merged["Forward_Rate"])
swap_2yr_merged["5yr2yr Annuity"] =annuity(2,5,swap_2yr_merged["Forward_Rate"])

# %%
swap_2yr_merged
# Out:
#             2yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29    0.0732     12.650    13.5668    16.9330     23.8020     38.8012
# 2021-01-28    0.0790     12.110    13.4767    16.6400     23.5950     38.2134
# 2021-01-27    0.0749     11.020    13.3201    16.4322     22.9946     37.5097
# 2021-01-26    0.0745     12.475    13.3633    16.9350     22.8690     37.3400
# 2021-01-25    0.0718     11.885    13.3430    17.2400     22.9350     37.8312
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06    1.3171     56.540    54.9493    57.8200     60.2395     63.1054
# 2020-02-05    1.3142     58.790    57.4622    58.5000     60.6495     63.3408
# 2020-02-04    1.2800     62.080    58.9966    58.9465     61.6259     64.0755
# 2020-02-03    1.2170     67.580    63.4823    62.8350     65.0052     65.9400
# 2020-01-31    1.1712     57.150    61.9829    60.0300     65.0545     66.8200
#
#             5yr Expiry  Forward_Rate  1m2yr Annuity  3m2yr Annuity  \
# Date
# 2021-01-29     60.1250      7.318661       1.998110       1.997989
# 2021-01-28     59.9200      7.898440       1.997961       1.997829
# 2021-01-27     59.6146      7.488598       1.998067       1.997942
# 2021-01-26     59.9083      7.448613       1.998077       1.997953
# 2021-01-25     60.5757      7.178711       1.998147       1.998027
# ...                ...           ...            ...            ...
# 2020-02-06     65.6474    131.278207       1.966425       1.964275
# 2020-02-05     65.8377    130.990102       1.966498       1.964353
# 2020-02-04     66.6980    127.592139       1.967359       1.965268
# 2020-02-03     67.6501    121.331223       1.968946       1.966956
# 2020-01-31     67.4369    116.778406       1.970101       1.968184
#
#             6m2yr Annuity  1yr2yr Annuity  2yr2yr Annuity  5yr2yr Annuity
# Date
# 2021-01-29       1.997806        1.997440        1.996709        1.994519
# 2021-01-28       1.997632        1.997238        1.996449        1.994085
# 2021-01-27       1.997755        1.997381        1.996633        1.994392
# 2021-01-26       1.997767        1.997395        1.996651        1.994422
# 2021-01-25       1.997848        1.997489        1.996772        1.994623
# ...                   ...             ...             ...             ...
# 2020-02-06       1.961055        1.954629        1.941841        1.903977
# 2020-02-05       1.961139        1.954727        1.941967        1.904182
# 2020-02-04       1.962136        1.955887        1.943449        1.906608
# 2020-02-03       1.963975        1.958027        1.946184        1.911085
# 2020-01-31       1.965313        1.959584        1.948176        1.914347
#
# [252 rows x 14 columns]

# %%
swap_2yr_merged["1m2yr Premium"]=bachelier_call(0,1/12,swap_2yr_merged['1m Expiry']/10000,swap_2yr_merged['1m2yr Annuity'])*10000
swap_2yr_merged["3m2yr Premium"]=bachelier_call(0,3/12,swap_2yr_merged['3m Expiry']/10000,swap_2yr_merged['3m2yr Annuity'])*10000
swap_2yr_merged["6m2yr Premium"]=bachelier_call(0,1/2,swap_2yr_merged['6m Expiry']/10000,swap_2yr_merged['6m2yr Annuity'])*10000
swap_2yr_merged["1yr2yr Premium"]=bachelier_call(0,1,swap_2yr_merged['1yr Expiry']/10000,swap_2yr_merged['1yr2yr Annuity'])*10000
swap_2yr_merged["2yr2yr Premium"]=bachelier_call(0,2,swap_2yr_merged['2yr Expiry']/10000,swap_2yr_merged['2yr2yr Annuity'])*10000
swap_2yr_merged["5yr2yr Premium"]=bachelier_call(0,5,swap_2yr_merged['5yr Expiry']/10000,swap_2yr_merged['5yr2yr Annuity'])*10000

# %%
swap_2yr_merged
# Out:
#             2yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29    0.0732     12.650    13.5668    16.9330     23.8020     38.8012
# 2021-01-28    0.0790     12.110    13.4767    16.6400     23.5950     38.2134
# 2021-01-27    0.0749     11.020    13.3201    16.4322     22.9946     37.5097
# 2021-01-26    0.0745     12.475    13.3633    16.9350     22.8690     37.3400
# 2021-01-25    0.0718     11.885    13.3430    17.2400     22.9350     37.8312
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06    1.3171     56.540    54.9493    57.8200     60.2395     63.1054
# 2020-02-05    1.3142     58.790    57.4622    58.5000     60.6495     63.3408
# 2020-02-04    1.2800     62.080    58.9966    58.9465     61.6259     64.0755
# 2020-02-03    1.2170     67.580    63.4823    62.8350     65.0052     65.9400
# 2020-01-31    1.1712     57.150    61.9829    60.0300     65.0545     66.8200
#
#             5yr Expiry  Forward_Rate  1m2yr Annuity  3m2yr Annuity  \
# Date
# 2021-01-29     60.1250      7.318661       1.998110       1.997989
# 2021-01-28     59.9200      7.898440       1.997961       1.997829
# 2021-01-27     59.6146      7.488598       1.998067       1.997942
# 2021-01-26     59.9083      7.448613       1.998077       1.997953
# 2021-01-25     60.5757      7.178711       1.998147       1.998027
# ...                ...           ...            ...            ...
# 2020-02-06     65.6474    131.278207       1.966425       1.964275
# 2020-02-05     65.8377    130.990102       1.966498       1.964353
# 2020-02-04     66.6980    127.592139       1.967359       1.965268
# 2020-02-03     67.6501    121.331223       1.968946       1.966956
# 2020-01-31     67.4369    116.778406       1.970101       1.968184
#
#             6m2yr Annuity  1yr2yr Annuity  2yr2yr Annuity  5yr2yr Annuity  \
# Date
# 2021-01-29       1.997806        1.997440        1.996709        1.994519
# 2021-01-28       1.997632        1.997238        1.996449        1.994085
# 2021-01-27       1.997755        1.997381        1.996633        1.994392
# 2021-01-26       1.997767        1.997395        1.996651        1.994422
# 2021-01-25       1.997848        1.997489        1.996772        1.994623
# ...                   ...             ...             ...             ...
# 2020-02-06       1.961055        1.954629        1.941841        1.903977
# 2020-02-05       1.961139        1.954727        1.941967        1.904182
# 2020-02-04       1.962136        1.955887        1.943449        1.906608
# 2020-02-03       1.963975        1.958027        1.946184        1.911085
# 2020-01-31       1.965313        1.959584        1.948176        1.914347
#
#             1m2yr Premium  3m2yr Premium  6m2yr Premium  1yr2yr Premium  \
# Date
# 2021-01-29       2.910915       5.406927       9.542941       18.966942
# 2021-01-28       2.786445       5.370590       9.376999       18.800084
# 2021-01-27       2.535777       5.308483       9.260469       18.323010
# 2021-01-26       2.870597       5.325729       9.543882       18.223054
# 2021-01-25       2.734928       5.317836       9.716161       18.276509
# ...                   ...            ...            ...             ...
# 2020-02-06      12.804208      21.530027      31.986214       46.973808
# 2020-02-05      13.314243      22.515512      32.363787       47.295899
# 2020-02-04      14.065486      23.127510      32.627384       48.085838
# 2020-02-03      15.323973      24.907340      34.812295       50.778140
# 2020-01-31      12.966539      24.334237      33.280913       50.857068
#
#             2yr2yr Premium  5yr2yr Premium
# Date
# 2021-01-29       43.710432      106.976472
# 2021-01-28       43.042647      106.588553
# 2021-01-27       42.253913      106.061592
# 2021-01-26       42.063127      106.585717
# 2021-01-25       42.619047      107.784029
# ...                    ...             ...
# 2020-02-06       69.136161      111.499845
# 2020-02-05       69.398548      111.835132
# 2020-02-04       70.257110      113.440782
# 2020-02-03       72.403233      115.330305
# 2020-01-31       73.444560      115.163097
#
# [252 rows x 20 columns]

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][14]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,1/12,0,0.4))
implied_vol_table_2yr=pd.DataFrame({"1m Implied Vol":price},index=swap_2yr_merged.index)
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_2yr
# Out:
#             1m Implied Vol
# Date
# 2021-01-29        3.453276
# 2021-01-28        3.062950
# 2021-01-27        2.939997
# 2021-01-26        3.346029
# 2021-01-25        3.307773
# ...                    ...
# 2020-02-06        0.844367
# 2020-02-05        0.879930
# 2020-02-04        0.954398
# 2020-02-03        1.093586
# 2020-01-31        0.961561
#
# [252 rows x 1 columns]

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][15]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,3/12,0,0.5))
implied_vol_table_2yr["3m Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_2yr
# Out:
#             1m Implied Vol  3m Implied Vol
# Date
# 2021-01-29        3.453276        3.705912
# 2021-01-28        3.062950        3.410840
# 2021-01-27        2.939997        3.555900
# 2021-01-26        3.346029        3.586597
# 2021-01-25        3.307773        3.715915
# ...                    ...             ...
# 2020-02-06        0.844367        0.820950
# 2020-02-05        0.879930        0.860370
# 2020-02-04        0.954398        0.907311
# 2020-02-03        1.093586        1.027579
# 2020-01-31        0.961561        1.043178
#
# [252 rows x 2 columns]

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][16]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,1/2,0,0.5))
implied_vol_table_2yr["6m Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: overflow encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][17]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,1,0,0.5))
implied_vol_table_2yr["1yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][18]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,2,0,0.5))
implied_vol_table_2yr["2yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: overflow encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)

# %%
price=[]
for i in range(len(swap_2yr_merged['2yr Swap'])):    
    price.append(implied_volatility_call(swap_2yr_merged.iloc[i][19]/10000,swap_2yr_merged.iloc[i][0]/100,swap_2yr_merged.iloc[i][0]/100,5,0,1.9))
implied_vol_table_2yr["5yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_2yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2021-01-29        3.453276        3.705912             NaN              NaN
# 2021-01-28        3.062950        3.410840             NaN              NaN
# 2021-01-27        2.939997        3.555900             NaN              NaN
# 2021-01-26        3.346029        3.586597             NaN              NaN
# 2021-01-25        3.307773        3.715915             NaN              NaN
# ...                    ...             ...             ...              ...
# 2020-02-06        0.844367        0.820950        0.864907         0.911808
# 2020-02-05        0.879930        0.860370        0.877039         0.920182
# 2020-02-04        0.954398        0.907311        0.907784         0.961010
# 2020-02-03        1.093586        1.027579        1.018635         1.098594
# 2020-01-31        0.961561        1.043178        1.011912         1.148403
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2021-01-29              NaN              NaN
# 2021-01-28              NaN              NaN
# 2021-01-27              NaN              NaN
# 2021-01-26              NaN              NaN
# 2021-01-25              NaN              NaN
# ...                     ...              ...
# 2020-02-06         0.829256              NaN
# 2020-02-05         0.820871              NaN
# 2020-02-04         0.777855              NaN
# 2020-02-03         1.077490              NaN
# 2020-01-31         1.264290              NaN
#
# [252 rows x 6 columns]

# %% [markdown]
# # 5 year Swap Dataframe

# %%
swap_5yr_merged=pd.merge(USS05,USS1m5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price_x':'5yr Swap'}, inplace = True)
swap_5yr_merged.rename(columns = {'Last Price_y':'1m Expiry'}, inplace = True)

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry
# Date
# 2023-04-19    3.4895   141.5000
# 2023-04-18    3.4729   137.7000
# 2023-04-17    3.4878   141.9000
# 2023-04-14    3.3861   137.3000
# 2023-04-13    3.2829   138.9000
# ...              ...        ...
# 2018-04-27    2.5250    50.6900
# 2018-04-26    2.5390    54.1110
# 2018-04-25    2.5640    57.4000
# 2018-04-24    2.5450    54.9393
# 2018-04-23    2.5380    55.1504
#
# [1266 rows x 2 columns]

# %%
swap_5yr_merged=pd.merge(swap_5yr_merged,USS3m5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price':'3m Expiry'}, inplace = True)

# %%
swap_5yr_merged=pd.merge(swap_5yr_merged,USS6m5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price':'6m Expiry'}, inplace = True)

# %%
swap_5yr_merged=pd.merge(swap_5yr_merged,USS1y5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price':'1yr Expiry'}, inplace = True)

# %%
swap_5yr_merged=pd.merge(swap_5yr_merged,USS2y5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price':'2yr Expiry'}, inplace = True)

# %%
swap_5yr_merged=pd.merge(swap_5yr_merged,USS5y5y,how='inner',on='Date')
swap_5yr_merged.rename(columns = {'Last Price':'5yr Expiry'}, inplace = True)

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2023-04-19    3.4895   141.5000   134.5000   130.3000    124.0000    114.5000
# 2023-04-18    3.4729   137.7000   132.2000   127.5000    121.2000    112.8000
# 2023-04-17    3.4878   141.9000   134.9000   129.8000    122.0000    113.4000
# 2023-04-14    3.3861   137.3000   130.9000   125.8000    118.3000    111.1000
# 2023-04-13    3.2829   138.9000   134.6000   127.9000    118.5000    111.2000
# ...              ...        ...        ...        ...         ...         ...
# 2018-04-27    2.5250    50.6900    55.0835    58.5890     63.1965     68.8900
# 2018-04-26    2.5390    54.1110    56.9000    59.8854     64.7100     70.2500
# 2018-04-25    2.5640    57.4000    59.9385    62.0000     66.5550     71.7000
# 2018-04-24    2.5450    54.9393    57.9323    60.6574     65.3160     70.5000
# 2018-04-23    2.5380    55.1504    57.7513    60.4709     64.9855     70.3905
#
#             5yr Expiry
# Date
# 2023-04-19     96.3000
# 2023-04-18     95.6000
# 2023-04-17     95.7000
# 2023-04-14     95.1000
# 2023-04-13     95.4000
# ...                ...
# 2018-04-27     73.2087
# 2018-04-26     73.9000
# 2018-04-25     74.8075
# 2018-04-24     74.0000
# 2018-04-23     73.4171
#
# [1254 rows x 7 columns]

# %%
swap_5yr_merged.to_excel("5 year Swap Merged.xlsx")

# %%
swap_5yr_merged=swap_5yr_merged.loc['2020-01-31':'2021-01-31']

# %%
fwd_rate=f = 2 * np.log(0.5 * (swap_5yr_merged["5yr Swap"]/100) + 1)*10000

# %%
swap_5yr_merged["Forward_Rate"] =fwd_rate

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29     0.344    36.7050    36.8296    41.1491     47.1000     53.9650
# 2021-01-28     0.341    35.5953    36.3502    40.6250     46.0050     53.4700
# 2021-01-27     0.321    33.5800    35.5877    40.2292     45.6839     53.3340
# 2021-01-26     0.326    32.7940    35.2114    39.9300     45.4488     53.2450
# 2021-01-25     0.319    33.7500    35.7565    40.9355     46.1331     53.4350
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06     1.272    64.1158    61.2069    62.8252     64.0125     64.6000
# 2020-02-05     1.268    66.3546    63.3463    65.5500     64.7669     65.1011
# 2020-02-04     1.219    72.1250    65.4700    64.8901     65.6837     66.0000
# 2020-02-03     1.146    75.8900    68.9577    68.7490     67.7449     67.6000
# 2020-01-31     1.105    75.9300    68.9950    67.3150     66.7950     67.0821
#
#             5yr Expiry  Forward_Rate
# Date
# 2021-01-29     63.7700     34.370450
# 2021-01-28     63.1515     34.070963
# 2021-01-27     62.8519     32.074267
# 2021-01-26     62.9100     32.573460
# 2021-01-25     63.5155     31.874587
# ...                ...           ...
# 2020-02-06     64.6200    126.797211
# 2020-02-05     65.4113    126.399735
# 2020-02-04     66.0377    121.530012
# 2020-02-03     66.9700    114.272920
# 2020-01-31     66.8569    110.195863
#
# [254 rows x 8 columns]

# %%
swap_5yr_merged["1m5yr Annuity"] =annuity(5,1/12,swap_5yr_merged["Forward_Rate"])
swap_5yr_merged["3m5yr Annuity"] =annuity(5,3/12,swap_5yr_merged["Forward_Rate"])
swap_5yr_merged["6m5yr Annuity"] =annuity(5,1/2,swap_5yr_merged["Forward_Rate"])
swap_5yr_merged["1yr5yr Annuity"] =annuity(5,1,swap_5yr_merged["Forward_Rate"])
swap_5yr_merged["2yr5yr Annuity"] =annuity(5,2,swap_5yr_merged["Forward_Rate"])
swap_5yr_merged["5yr5yr Annuity"] =annuity(5,5,swap_5yr_merged["Forward_Rate"])

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29     0.344    36.7050    36.8296    41.1491     47.1000     53.9650
# 2021-01-28     0.341    35.5953    36.3502    40.6250     46.0050     53.4700
# 2021-01-27     0.321    33.5800    35.5877    40.2292     45.6839     53.3340
# 2021-01-26     0.326    32.7940    35.2114    39.9300     45.4488     53.2450
# 2021-01-25     0.319    33.7500    35.7565    40.9355     46.1331     53.4350
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06     1.272    64.1158    61.2069    62.8252     64.0125     64.6000
# 2020-02-05     1.268    66.3546    63.3463    65.5500     64.7669     65.1011
# 2020-02-04     1.219    72.1250    65.4700    64.8901     65.6837     66.0000
# 2020-02-03     1.146    75.8900    68.9577    68.7490     67.7449     67.6000
# 2020-01-31     1.105    75.9300    68.9950    67.3150     66.7950     67.0821
#
#             5yr Expiry  Forward_Rate  1m5yr Annuity  3m5yr Annuity  \
# Date
# 2021-01-29     63.7700     34.370450       4.952314       4.950896
# 2021-01-28     63.1515     34.070963       4.952727       4.951321
# 2021-01-27     62.8519     32.074267       4.955482       4.954158
# 2021-01-26     62.9100     32.573460       4.954793       4.953448
# 2021-01-25     63.5155     31.874587       4.955758       4.954441
# ...                ...           ...            ...            ...
# 2020-02-06     64.6200    126.797211       4.826908       4.821811
# 2020-02-05     65.4113    126.399735       4.827439       4.822357
# 2020-02-04     66.0377    121.530012       4.833946       4.829053
# 2020-02-03     66.9700    114.272920       4.843664       4.839053
# 2020-01-31     66.8569    110.195863       4.849134       4.844683
#
#             6m5yr Annuity  1yr5yr Annuity  2yr5yr Annuity  5yr5yr Annuity
# Date
# 2021-01-29       4.948770        4.944519        4.936029        4.910647
# 2021-01-28       4.949213        4.944999        4.936582        4.911418
# 2021-01-27       4.952172        4.948203        4.940273        4.916562
# 2021-01-26       4.951432        4.947401        4.939350        4.915275
# 2021-01-25       4.952468        4.948523        4.940643        4.917077
# ...                   ...             ...             ...             ...
# 2020-02-06       4.814174        4.798938        4.768609        4.678770
# 2020-02-05       4.814743        4.799553        4.769315        4.679741
# 2020-02-04       4.821722        4.807095        4.777973        4.691662
# 2020-02-03       4.832146        4.818361        4.790909        4.709488
# 2020-01-31       4.838014        4.824704        4.798194        4.719535
#
# [254 rows x 14 columns]

# %%
swap_5yr_merged["1m5yr Premium"]=bachelier_call(0,1/12,swap_5yr_merged['1m Expiry']/10000,swap_5yr_merged['1m5yr Annuity'])*10000
swap_5yr_merged["3m5yr Premium"]=bachelier_call(0,3/12,swap_5yr_merged['3m Expiry']/10000,swap_5yr_merged['3m5yr Annuity'])*10000
swap_5yr_merged["6m5yr Premium"]=bachelier_call(0,1/2,swap_5yr_merged['6m Expiry']/10000,swap_5yr_merged['6m5yr Annuity'])*10000
swap_5yr_merged["1yr5yr Premium"]=bachelier_call(0,1,swap_5yr_merged['1yr Expiry']/10000,swap_5yr_merged['1yr5yr Annuity'])*10000
swap_5yr_merged["2yr5yr Premium"]=bachelier_call(0,2,swap_5yr_merged['2yr Expiry']/10000,swap_5yr_merged['2yr5yr Annuity'])*10000
swap_5yr_merged["5yr5yr Premium"]=bachelier_call(0,5,swap_5yr_merged['5yr Expiry']/10000,swap_5yr_merged['5yr5yr Annuity'])*10000

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29     0.344    36.7050    36.8296    41.1491     47.1000     53.9650
# 2021-01-28     0.341    35.5953    36.3502    40.6250     46.0050     53.4700
# 2021-01-27     0.321    33.5800    35.5877    40.2292     45.6839     53.3340
# 2021-01-26     0.326    32.7940    35.2114    39.9300     45.4488     53.2450
# 2021-01-25     0.319    33.7500    35.7565    40.9355     46.1331     53.4350
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06     1.272    64.1158    61.2069    62.8252     64.0125     64.6000
# 2020-02-05     1.268    66.3546    63.3463    65.5500     64.7669     65.1011
# 2020-02-04     1.219    72.1250    65.4700    64.8901     65.6837     66.0000
# 2020-02-03     1.146    75.8900    68.9577    68.7490     67.7449     67.6000
# 2020-01-31     1.105    75.9300    68.9950    67.3150     66.7950     67.0821
#
#             5yr Expiry  Forward_Rate  1m5yr Annuity  3m5yr Annuity  \
# Date
# 2021-01-29     63.7700     34.370450       4.952314       4.950896
# 2021-01-28     63.1515     34.070963       4.952727       4.951321
# 2021-01-27     62.8519     32.074267       4.955482       4.954158
# 2021-01-26     62.9100     32.573460       4.954793       4.953448
# 2021-01-25     63.5155     31.874587       4.955758       4.954441
# ...                ...           ...            ...            ...
# 2020-02-06     64.6200    126.797211       4.826908       4.821811
# 2020-02-05     65.4113    126.399735       4.827439       4.822357
# 2020-02-04     66.0377    121.530012       4.833946       4.829053
# 2020-02-03     66.9700    114.272920       4.843664       4.839053
# 2020-01-31     66.8569    110.195863       4.849134       4.844683
#
#             6m5yr Annuity  1yr5yr Annuity  2yr5yr Annuity  5yr5yr Annuity  \
# Date
# 2021-01-29       4.948770        4.944519        4.936029        4.910647
# 2021-01-28       4.949213        4.944999        4.936582        4.911418
# 2021-01-27       4.952172        4.948203        4.940273        4.916562
# 2021-01-26       4.951432        4.947401        4.939350        4.915275
# 2021-01-25       4.952468        4.948523        4.940643        4.917077
# ...                   ...             ...             ...             ...
# 2020-02-06       4.814174        4.798938        4.768609        4.678770
# 2020-02-05       4.814743        4.799553        4.769315        4.679741
# 2020-02-04       4.821722        4.807095        4.777973        4.691662
# 2020-02-03       4.832146        4.818361        4.790909        4.709488
# 2020-01-31       4.838014        4.824704        4.798194        4.719535
#
#             1m5yr Premium  3m5yr Premium  6m5yr Premium  1yr5yr Premium  \
# Date
# 2021-01-29      20.934032      36.371473      57.445053       92.908410
# 2021-01-28      20.302827      35.901119      56.718482       90.757251
# 2021-01-27      19.163995      35.168174      56.199464       90.182175
# 2021-01-26      18.712825      34.791328      55.773152       89.703552
# 2021-01-25      19.262084      35.337008      57.189570       91.074815
# ...                   ...            ...            ...             ...
# 2020-02-06      35.641301      58.869535      85.319982      122.551881
# 2020-02-05      36.889882      60.934135      89.030930      124.012069
# 2020-02-04      40.151988      63.064414      88.262397      125.965143
# 2020-02-03      42.332895      66.561522      93.713360      130.222499
# 2020-01-31      42.403043      66.675005      91.870075      128.565586
#
#             2yr5yr Premium  5yr5yr Premium
# Date
# 2021-01-29      150.284764      279.350954
# 2021-01-28      148.922953      276.684994
# 2021-01-27      148.655233      275.660799
# 2021-01-26      148.379439      275.843409
# 2021-01-25      148.947879      278.600436
# ...                    ...             ...
# 2020-02-06      173.799827      269.707909
# 2020-02-05      175.173913      273.067292
# 2020-02-04      177.915063      276.384545
# 2020-02-03      182.721524      281.351414
# 2020-01-31      181.597370      281.475453
#
# [254 rows x 20 columns]

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][14]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,1/12,0,0.3))
implied_vol_table_5yr=pd.DataFrame({"1m Implied Vol":price},index=swap_5yr_merged.index)
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_5yr
# Out:
#             1m Implied Vol
# Date
# 2021-01-29        5.755667
# 2021-01-28        5.613032
# 2021-01-27        5.630519
# 2021-01-26        5.383549
# 2021-01-25        5.704368
# ...                    ...
# 2020-02-06        2.433135
# 2020-02-05        2.526313
# 2020-02-04        2.939376
# 2020-02-03        3.318641
# 2020-01-31        3.456310
#
# [254 rows x 1 columns]

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][15]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,3/12,0,2))
implied_vol_table_5yr["3m Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: overflow encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)

# %%
implied_vol_table_5yr
# Out:
#             1m Implied Vol  3m Implied Vol
# Date
# 2021-01-29        5.755667             NaN
# 2021-01-28        5.613032             NaN
# 2021-01-27        5.630519             NaN
# 2021-01-26        5.383549             NaN
# 2021-01-25        5.704368             NaN
# ...                    ...             ...
# 2020-02-06        2.433135        2.457943
# 2020-02-05        2.526313        2.562431
# 2020-02-04        2.939376        2.782557
# 2020-02-03        3.318641        3.173802
# 2020-01-31        3.456310        3.369952
#
# [254 rows x 2 columns]

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][16]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,1/2,0,0.5))
implied_vol_table_5yr["6m Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: overflow encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)

# %%
implied_vol_table_5yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol
# Date
# 2021-01-29        5.755667             NaN             NaN
# 2021-01-28        5.613032             NaN             NaN
# 2021-01-27        5.630519             NaN             NaN
# 2021-01-26        5.383549             NaN             NaN
# 2021-01-25        5.704368             NaN             NaN
# ...                    ...             ...             ...
# 2020-02-06        2.433135        2.457943        2.729187
# 2020-02-05        2.526313        2.562431        2.900106
# 2020-02-04        2.939376        2.782557        3.061018
# 2020-02-03        3.318641        3.173802        3.733134
# 2020-01-31        3.456310        3.369952        3.843498
#
# [254 rows x 3 columns]

# %%
implied_vol_table_5yr.to_excel("output2.xlsx")

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][17]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,1,0,0.5))
implied_vol_table_5yr["1yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][18]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,2,0,0.5))
implied_vol_table_5yr["2yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: overflow encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: overflow encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)

# %%
price=[]
for i in range(len(swap_5yr_merged['5yr Swap'])):    
    price.append(implied_volatility_call(swap_5yr_merged.iloc[i][19]/10000,swap_5yr_merged.iloc[i][0]/100,swap_5yr_merged.iloc[i][0]/100,5,0,0.5))
implied_vol_table_5yr["5yr Implied Vol"] =price
# Out:
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:77: RuntimeWarning: divide by zero encountered in double_scalars
#   sigma = sigma - diff / vega(S, K, T, r, sigma)
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / (sigma * np.sqrt(T))
# /var/folders/4r/rql3t4852cx_plttsp1tt4jh0000gn/T/ipykernel_51597/2888101276.py:38: RuntimeWarning: invalid value encountered in double_scalars
#   d1 = (np.log(S / K) + (r + sigma ** 2 / 2) * T) / sigma * np.sqrt(T)

# %%
implied_vol_table_5yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2021-01-29        5.755667             NaN             NaN              NaN
# 2021-01-28        5.613032             NaN             NaN              NaN
# 2021-01-27        5.630519             NaN             NaN              NaN
# 2021-01-26        5.383549             NaN             NaN              NaN
# 2021-01-25        5.704368             NaN             NaN              NaN
# ...                    ...             ...             ...              ...
# 2020-02-06        2.433135        2.457943        2.729187         4.162536
# 2020-02-05        2.526313        2.562431        2.900106         4.513165
# 2020-02-04        2.939376        2.782557        3.061018              NaN
# 2020-02-03        3.318641        3.173802        3.733134              NaN
# 2020-01-31        3.456310        3.369952        3.843498              NaN
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2021-01-29              NaN              NaN
# 2021-01-28              NaN              NaN
# 2021-01-27              NaN              NaN
# 2021-01-26              NaN              NaN
# 2021-01-25              NaN              NaN
# ...                     ...              ...
# 2020-02-06              NaN              NaN
# 2020-02-05              NaN              NaN
# 2020-02-04              NaN              NaN
# 2020-02-03              NaN              NaN
# 2020-01-31              NaN              NaN
#
# [254 rows x 6 columns]

# %%
implied_vol_table_5yr.to_excel("output2.xlsx")

# %%
plt.figure(figsize=(15, 10))
plt.plot(implied_vol_table_5yr.index, implied_vol_table_5yr['6m Implied Vol'], label = "implied vol")
#plt.plot(swap_30yr_merged.index, swap_30yr_merged['1m Expiry'], label = "realised vol")

# %%
plt.figure(figsize=(15, 10))
#plt.plot(implied_vol_table_30yr.index, implied_vol_table_30yr['1m Implied Vol'], label = "implied vol")
plt.plot(swap_5yr_merged.index, swap_5yr_merged['6m Expiry'], label = "realised vol")

# %%
swap_5yr_merged
# Out:
#             5yr Swap  1m Expiry  3m Expiry  6m Expiry  1yr Expiry  2yr Expiry  \
# Date
# 2021-01-29     0.344    36.7050    36.8296    41.1491     47.1000     53.9650
# 2021-01-28     0.341    35.5953    36.3502    40.6250     46.0050     53.4700
# 2021-01-27     0.321    33.5800    35.5877    40.2292     45.6839     53.3340
# 2021-01-26     0.326    32.7940    35.2114    39.9300     45.4488     53.2450
# 2021-01-25     0.319    33.7500    35.7565    40.9355     46.1331     53.4350
# ...              ...        ...        ...        ...         ...         ...
# 2020-02-06     1.272    64.1158    61.2069    62.8252     64.0125     64.6000
# 2020-02-05     1.268    66.3546    63.3463    65.5500     64.7669     65.1011
# 2020-02-04     1.219    72.1250    65.4700    64.8901     65.6837     66.0000
# 2020-02-03     1.146    75.8900    68.9577    68.7490     67.7449     67.6000
# 2020-01-31     1.105    75.9300    68.9950    67.3150     66.7950     67.0821
#
#             5yr Expiry  Forward_Rate  1m5yr Annuity  3m5yr Annuity  \
# Date
# 2021-01-29     63.7700     34.370450       4.952314       4.950896
# 2021-01-28     63.1515     34.070963       4.952727       4.951321
# 2021-01-27     62.8519     32.074267       4.955482       4.954158
# 2021-01-26     62.9100     32.573460       4.954793       4.953448
# 2021-01-25     63.5155     31.874587       4.955758       4.954441
# ...                ...           ...            ...            ...
# 2020-02-06     64.6200    126.797211       4.826908       4.821811
# 2020-02-05     65.4113    126.399735       4.827439       4.822357
# 2020-02-04     66.0377    121.530012       4.833946       4.829053
# 2020-02-03     66.9700    114.272920       4.843664       4.839053
# 2020-01-31     66.8569    110.195863       4.849134       4.844683
#
#             6m5yr Annuity  1yr5yr Annuity  2yr5yr Annuity  5yr5yr Annuity  \
# Date
# 2021-01-29       4.948770        4.944519        4.936029        4.910647
# 2021-01-28       4.949213        4.944999        4.936582        4.911418
# 2021-01-27       4.952172        4.948203        4.940273        4.916562
# 2021-01-26       4.951432        4.947401        4.939350        4.915275
# 2021-01-25       4.952468        4.948523        4.940643        4.917077
# ...                   ...             ...             ...             ...
# 2020-02-06       4.814174        4.798938        4.768609        4.678770
# 2020-02-05       4.814743        4.799553        4.769315        4.679741
# 2020-02-04       4.821722        4.807095        4.777973        4.691662
# 2020-02-03       4.832146        4.818361        4.790909        4.709488
# 2020-01-31       4.838014        4.824704        4.798194        4.719535
#
#             1m5yr Premium  3m5yr Premium  6m5yr Premium  1yr5yr Premium  \
# Date
# 2021-01-29      20.934032      36.371473      57.445053       92.908410
# 2021-01-28      20.302827      35.901119      56.718482       90.757251
# 2021-01-27      19.163995      35.168174      56.199464       90.182175
# 2021-01-26      18.712825      34.791328      55.773152       89.703552
# 2021-01-25      19.262084      35.337008      57.189570       91.074815
# ...                   ...            ...            ...             ...
# 2020-02-06      35.641301      58.869535      85.319982      122.551881
# 2020-02-05      36.889882      60.934135      89.030930      124.012069
# 2020-02-04      40.151988      63.064414      88.262397      125.965143
# 2020-02-03      42.332895      66.561522      93.713360      130.222499
# 2020-01-31      42.403043      66.675005      91.870075      128.565586
#
#             2yr5yr Premium  5yr5yr Premium
# Date
# 2021-01-29      150.284764      279.350954
# 2021-01-28      148.922953      276.684994
# 2021-01-27      148.655233      275.660799
# 2021-01-26      148.379439      275.843409
# 2021-01-25      148.947879      278.600436
# ...                    ...             ...
# 2020-02-06      173.799827      269.707909
# 2020-02-05      175.173913      273.067292
# 2020-02-04      177.915063      276.384545
# 2020-02-03      182.721524      281.351414
# 2020-01-31      181.597370      281.475453
#
# [254 rows x 20 columns]

# %%
implied_vol_table_1yr.to_excel("1 year Swap Vol table_secondperiod.xlsx")

# %%
implied_vol_table_5yr
# Out:
#             1m Implied Vol  3m Implied Vol  6m Implied Vol  1yr Implied Vol  \
# Date
# 2021-01-29        5.755667             NaN             NaN              NaN
# 2021-01-28        5.613032             NaN             NaN              NaN
# 2021-01-27        5.630519             NaN             NaN              NaN
# 2021-01-26        5.383549             NaN             NaN              NaN
# 2021-01-25        5.704368             NaN             NaN              NaN
# ...                    ...             ...             ...              ...
# 2020-02-06        2.433135        2.457943        2.729187         4.162536
# 2020-02-05        2.526313        2.562431        2.900106         4.513165
# 2020-02-04        2.939376        2.782557        3.061018              NaN
# 2020-02-03        3.318641        3.173802        3.733134              NaN
# 2020-01-31        3.456310        3.369952        3.843498              NaN
#
#             2yr Implied Vol  5yr Implied Vol
# Date
# 2021-01-29              NaN              NaN
# 2021-01-28              NaN              NaN
# 2021-01-27              NaN              NaN
# 2021-01-26              NaN              NaN
# 2021-01-25              NaN              NaN
# ...                     ...              ...
# 2020-02-06              NaN              NaN
# 2020-02-05              NaN              NaN
# 2020-02-04              NaN              NaN
# 2020-02-03              NaN              NaN
# 2020-01-31              NaN              NaN
#
# [254 rows x 6 columns]

# %%
swap_2yr_merged.to_excel("2 year Swap Merged.xlsx")
